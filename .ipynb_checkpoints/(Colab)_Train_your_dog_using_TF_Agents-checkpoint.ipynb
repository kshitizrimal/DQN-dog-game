# %% [markdown]
# # Train your dog using TF-Agents

# %%
# !pip install tf-agents

# %% [markdown]
# ### Imports

# %%
from enum import Enum
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tf_agents.environments import py_environment
from tf_agents.environments import tf_environment
from tf_agents.environments import tf_py_environment
from tf_agents.environments import utils
from tf_agents.specs import array_spec
from tf_agents.trajectories import time_step as timeStep

from tf_agents.policies import random_tf_policy

from tf_agents.metrics import tf_py_metric
from tf_agents.metrics import tf_metrics
from tf_agents.metrics import py_metric
from tf_agents.drivers import py_driver
from tf_agents.drivers import dynamic_episode_driver

from tf_agents.agents.dqn import dqn_agent
from tf_agents.drivers import dynamic_step_driver
from tf_agents.networks import q_network
from tf_agents.replay_buffers import tf_uniform_replay_buffer

from tf_agents.policies import random_tf_policy
from tf_agents.trajectories import trajectory
from tf_agents.utils import common

from tf_agents.policies import policy_saver

# %%
def column(matrix, i):
    return [row[i] for row in matrix]

# %% [markdown]
# ### Game Environment

# %%
class ActionResult(Enum):
    VALID_MOVE = 1
    ILLEGAL_MOVE = 2
    FOUND_BONE = 3
    FOUND_POLICE = 4
    GAME_COMPLETE = 5

# %%
class DogAdventure():
    def __init__(self):
        self._state = np.zeros((36,),dtype=np.int32)
        self._police_locations = [6,10,14,25,33]
        self._bone_locations = [5,7,9,16,19,26,30]
        self._state[self._police_locations] = 2
        self._state[self._bone_locations] = 3
        self._state[0] = 1
        self._game_ended = False

    def reset(self):
        self._state = np.zeros((36,),dtype=np.int32)
        self._state[self._police_locations] = 2
        self._state[self._bone_locations] = 3
        self._state[0] = 1
        self._game_ended = False

    def __is_spot_last(self, position):
        return position == 35

    def move_dog(self, current_position, next_position):

        if self.__is_spot_last(next_position):
            self._state[current_position] = 0
            self._state[next_position] = 1

            self._game_ended = True
            return ActionResult.GAME_COMPLETE

        if next_position < 0 or next_position > (len(self._state) - 1):
            self._game_ended = True
            return ActionResult.ILLEGAL_MOVE

        if self._state[next_position] == 2:
            self._game_ended = True
            return ActionResult.FOUND_POLICE

        if self._state[next_position] == 3:
            self._state[current_position] = 0
            self._state[next_position] = 1
            return ActionResult.FOUND_BONE

        self._state[current_position] = 0
        self._state[next_position] = 1

        return ActionResult.VALID_MOVE

    def game_ended(self):
        return self._game_ended
  
    def game_state(self):
        return self._state

# %%
class DogAdventureEnvironment(py_environment.PyEnvironment):

    def __init__(self, game):
        self._action_spec = array_spec.BoundedArraySpec(
            shape=(), dtype=np.int32, minimum=0, maximum=3, name='action')
        self._observation_spec = array_spec.BoundedArraySpec(
            shape=(36,), dtype=np.int32, minimum=0, maximum=3, name='observation')

        # 0=>Left, 1=>Right, 2=>Down, 3=>Up
        self._action_values = {0:-1,1:1,2:-6,3:6}
        self._game = game

    def action_spec(self):
        return self._action_spec

    def observation_spec(self):
        return self._observation_spec

    def _reset(self):
        self._game.reset()
        return timeStep.restart(self._game.game_state())
  
    def _step(self, action):    

        if self._game.game_ended():
            return self.reset()

        action = action.item()

        next_agent_position_direction = self._action_values.get(action)
        current_agent_position = np.where(self._game.game_state() == 1)[0].item()
        new_agent_position = current_agent_position + next_agent_position_direction

        response = self._game.move_dog(current_agent_position,new_agent_position)

        if response == ActionResult.GAME_COMPLETE:
            return timeStep.termination(self._game.game_state(), 10)

        elif response == ActionResult.ILLEGAL_MOVE:
            return timeStep.termination(self._game.game_state(), -0.1)

        elif response == ActionResult.FOUND_POLICE:
            return timeStep.termination(self._game.game_state(), -0.1)

        elif response == ActionResult.FOUND_BONE:
            return timeStep.transition(self._game.game_state(), reward=1, discount=1.0)

        return timeStep.transition(self._game.game_state(), reward=-0.3, discount=1.0)

# %%
dogEnvironemt = DogAdventureEnvironment(DogAdventure())
utils.validate_py_environment(dogEnvironemt, episodes=5)

# %%
train_env = tf_py_environment.TFPyEnvironment(dogEnvironemt)
eval_env = tf_py_environment.TFPyEnvironment(dogEnvironemt)

# %% [markdown]
# ### DQN Setup

# %%
fc_layer_params = [32,64,128]

q_net = q_network.QNetwork(
            train_env.observation_spec(),
            train_env.action_spec(),
            fc_layer_params = fc_layer_params
        )

train_step = tf.Variable(0)
update_period = 4
optimizer = tf.keras.optimizers.RMSprop(lr=2.5e-4, rho=0.95, momentum=0.0, epsilon=0.00001, centered=True)

epsilon_fn = tf.keras.optimizers.schedules.PolynomialDecay(
                initial_learning_rate=1.0, 
                decay_steps=250000 // update_period,
                end_learning_rate=0.01)

agent = dqn_agent.DdqnAgent(
        train_env.time_step_spec(),
        train_env.action_spec(),
        q_network=q_net,
        optimizer=optimizer,
        target_update_period=2000,
        td_errors_loss_fn=tf.keras.losses.Huber(reduction="none"),
        gamma=0.99,
        train_step_counter=train_step,
        epsilon_greedy=lambda: epsilon_fn(train_step))

agent.initialize()

# %% [markdown]
# ### Replay Buffer Setup

# %%
replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
    data_spec=agent.collect_data_spec,
    batch_size=train_env.batch_size,
    max_length=1000000)

replay_buffer_observer = replay_buffer.add_batch

# %% [markdown]
# ### Metrics Setup

# %%
train_metrics = [tf_metrics.AverageReturnMetric(), tf_metrics.AverageEpisodeLengthMetric()]

# %% [markdown]
# ### Driver Setup

# %%
collect_driver = dynamic_step_driver.DynamicStepDriver(
    train_env,
    agent.collect_policy,
    observers=[replay_buffer_observer] + train_metrics,
    num_steps=update_period)

# %% [markdown]
# ### Collect trajectories using Random Policy

# %%
class ShowProgress:
    def __init__(self, total):
        self.counter = 0
        self.total = total
    def __call__(self, trajectory):
        if not trajectory.is_boundary():
            self.counter += 1
        if self.counter % 100 == 0:
            print("\r{}/{}".format(self.counter, self.total), end="")

# %%
initial_collect_policy = random_tf_policy.RandomTFPolicy(train_env.time_step_spec(), train_env.action_spec())

init_driver = dynamic_step_driver.DynamicStepDriver(
    train_env,
    initial_collect_policy,
    observers=[replay_buffer.add_batch, ShowProgress(20000)],
    num_steps=20000)

final_time_step, final_policy_state = init_driver.run()
# Out:
# 20000/20000

# %% [markdown]
# ### Verify collected trajectories

# %%
trajectories, buffer_info = replay_buffer.get_next(sample_batch_size=2, num_steps=3)

# %%
trajectories._fields
# Out:
# ('step_type',
#  'observation',
#  'action',
#  'policy_info',
#  'next_step_type',
#  'reward',
#  'discount')

# %%
time_steps, action_steps, next_time_steps = trajectory.to_transition(trajectories)
time_steps.observation.shape
# Out:
# TensorShape([2, 2, 36])

# %% [markdown]
# ### Create Dataset from Replay Buffer

# %%
dataset = replay_buffer.as_dataset(sample_batch_size=64, num_steps=2, num_parallel_calls=3).prefetch(3)

# %% [markdown]
# ### Run it under common function to make it faster

# %%
collect_driver.run = common.function(collect_driver.run)
agent.train = common.function(agent.train)

# %% [markdown]
# ### Train

# %%
all_train_loss = []
all_metrics = []

# %%
def train_agent(n_iterations):
    time_step = None
    policy_state = agent.collect_policy.get_initial_state(train_env.batch_size)
    iterator = iter(dataset)
    
    for iteration in range(n_iterations):
        current_metrics = []
        
        time_step, policy_state = collect_driver.run(time_step, policy_state)
        trajectories, buffer_info = next(iterator)
        
        train_loss = agent.train(trajectories)
        all_train_loss.append(train_loss.loss.numpy())

        for i in range(len(train_metrics)):
            current_metrics.append(train_metrics[i].result().numpy())
            
        all_metrics.append(current_metrics)
        
        if iteration % 500 == 0:
            print("\nIteration: {}, loss:{:.2f}".format(iteration, train_loss.loss.numpy()))
            
            for i in range(len(train_metrics)):
                print('{}: {}'.format(train_metrics[i].name, train_metrics[i].result().numpy()))

# %%
train_agent(150000)
# Out:
# Iteration: 0, loss:0.08
# AverageReturn: -0.10000000149011612
# AverageEpisodeLength: 1.0
#
# Iteration: 500, loss:0.02
# AverageReturn: -0.10000000149011612
# AverageEpisodeLength: 1.0
#
# Iteration: 1000, loss:0.02
# AverageReturn: -0.2500000298023224
# AverageEpisodeLength: 1.5
#
# Iteration: 1500, loss:0.02
# AverageReturn: -0.1600000113248825
# AverageEpisodeLength: 1.2000000476837158
#
# Iteration: 2000, loss:0.05
# AverageReturn: -0.10000000149011612
# AverageEpisodeLength: 1.0
#
# Iteration: 2500, loss:0.03
# AverageReturn: -0.37000003457069397
# AverageEpisodeLength: 1.899999976158142
#
# Iteration: 3000, loss:0.02
# AverageReturn: -0.17000003159046173
# AverageEpisodeLength: 3.4000000953674316
#
# Iteration: 3500, loss:0.04
# AverageReturn: -0.6800001263618469
# AverageEpisodeLength: 3.799999952316284
#
# Iteration: 4000, loss:0.04
# AverageReturn: -0.07000000774860382
# AverageEpisodeLength: 2.200000047683716
#
# Iteration: 4500, loss:0.01
# AverageReturn: -0.06000000238418579
# AverageEpisodeLength: 1.2999999523162842
#
# Iteration: 5000, loss:0.01
# AverageReturn: -0.09000001847743988
# AverageEpisodeLength: 2.700000047683716
#
# Iteration: 5500, loss:0.01
# AverageReturn: -0.07000000774860382
# AverageEpisodeLength: 2.200000047683716
#
# Iteration: 6000, loss:0.01
# AverageReturn: -0.10000000149011612
# AverageEpisodeLength: 1.0
#
# Iteration: 6500, loss:0.01
# AverageReturn: -0.1900000125169754
# AverageEpisodeLength: 1.2999999523162842
#
# Iteration: 7000, loss:0.01
# AverageReturn: -0.17000003159046173
# AverageEpisodeLength: 3.4000000953674316
#
# Iteration: 7500, loss:0.01
# AverageReturn: -0.25
# AverageEpisodeLength: 1.5
#
# Iteration: 8000, loss:0.03
# AverageReturn: -0.2600000500679016
# AverageEpisodeLength: 2.4000000953674316
#
# Iteration: 8500, loss:0.02
# AverageReturn: -0.3400000333786011
# AverageEpisodeLength: 3.0999999046325684
#
# Iteration: 9000, loss:0.02
# AverageReturn: -0.4699999690055847
# AverageEpisodeLength: 3.0999999046325684
#
# Iteration: 9500, loss:0.02
# AverageReturn: -0.1600000113248825
# AverageEpisodeLength: 1.2000000476837158
#
# Iteration: 10000, loss:0.03
# AverageReturn: -0.010000024922192097
# AverageEpisodeLength: 2.0
#
# Iteration: 10500, loss:0.02
# AverageReturn: -0.2600000202655792
# AverageEpisodeLength: 2.4000000953674316
#
# Iteration: 11000, loss:0.02
# AverageReturn: -0.47000008821487427
# AverageEpisodeLength: 3.0999999046325684
#
# Iteration: 11500, loss:0.02
# AverageReturn: -0.11000001430511475
# AverageEpisodeLength: 1.899999976158142
#
# Iteration: 12000, loss:0.04
# AverageReturn: -0.37000003457069397
# AverageEpisodeLength: 3.200000047683716
#
# Iteration: 12500, loss:0.04
# AverageReturn: -0.130000039935112
# AverageEpisodeLength: 2.4000000953674316
#
# Iteration: 13000, loss:0.04
# AverageReturn: -0.18000000715255737
# AverageEpisodeLength: 1.7000000476837158
#
# Iteration: 13500, loss:0.03
# AverageReturn: -0.49000006914138794
# AverageEpisodeLength: 3.5999999046325684
#
# Iteration: 14000, loss:0.06
# AverageReturn: 0.9000000953674316
# AverageEpisodeLength: 3.200000047683716
#
# Iteration: 14500, loss:0.16
# AverageReturn: -0.05000001937150955
# AverageEpisodeLength: 3.0
#
# Iteration: 15000, loss:0.05
# AverageReturn: -0.08000002056360245
# AverageEpisodeLength: 3.0999999046325684
#
# Iteration: 15500, loss:0.05
# AverageReturn: -0.37000003457069397
# AverageEpisodeLength: 4.5
#
# Iteration: 16000, loss:0.07
# AverageReturn: -0.4099999964237213
# AverageEpisodeLength: 2.9000000953674316
#
# Iteration: 16500, loss:0.06
# AverageReturn: -0.34000006318092346
# AverageEpisodeLength: 4.400000095367432
#
# Iteration: 17000, loss:0.05
# AverageReturn: -0.3500000238418579
# AverageEpisodeLength: 2.700000047683716
#
# Iteration: 17500, loss:0.07
# AverageReturn: -0.21000000834465027
# AverageEpisodeLength: 1.7999999523162842
#
# Iteration: 18000, loss:0.08
# AverageReturn: -0.06000002101063728
# AverageEpisodeLength: 3.9000000953674316
#
# Iteration: 18500, loss:0.07
# AverageReturn: -0.1900000274181366
# AverageEpisodeLength: 2.5999999046325684
#
# Iteration: 19000, loss:0.06
# AverageReturn: -0.15000000596046448
# AverageEpisodeLength: 1.600000023841858
#
# Iteration: 19500, loss:0.07
# AverageReturn: 0.7699998617172241
# AverageEpisodeLength: 4.5
#
# Iteration: 20000, loss:0.10
# AverageReturn: -0.36000001430511475
# AverageEpisodeLength: 2.299999952316284
#
# Iteration: 20500, loss:0.08
# AverageReturn: 0.7700001001358032
# AverageEpisodeLength: 5.800000190734863
#
# Iteration: 21000, loss:0.08
# AverageReturn: -0.11000003665685654
# AverageEpisodeLength: 4.5
#
# Iteration: 21500, loss:0.07
# AverageReturn: -0.2199999988079071
# AverageEpisodeLength: 5.300000190734863
#
# Iteration: 22000, loss:0.10
# AverageReturn: 0.04999997094273567
# AverageEpisodeLength: 3.0999999046325684
#
# Iteration: 22500, loss:0.09
# AverageReturn: 0.9699999690055847
# AverageEpisodeLength: 4.699999809265137
#
# Iteration: 23000, loss:0.08
# AverageReturn: -0.07000002264976501
# AverageEpisodeLength: 3.5
#
# Iteration: 23500, loss:0.09
# AverageReturn: 0.07999996840953827
# AverageEpisodeLength: 4.300000190734863
#
# Iteration: 24000, loss:0.11
# AverageReturn: 0.24999995529651642
# AverageEpisodeLength: 3.299999952316284
#
# Iteration: 24500, loss:0.11
# AverageReturn: -2.6822089438383045e-08
# AverageEpisodeLength: 3.700000047683716
#
# Iteration: 25000, loss:0.10
# AverageReturn: -0.2300000637769699
# AverageEpisodeLength: 3.5999999046325684
#
# Iteration: 25500, loss:0.11
# AverageReturn: 1.1799999475479126
# AverageEpisodeLength: 4.0
#
# Iteration: 26000, loss:0.16
# AverageReturn: -0.030000006780028343
# AverageEpisodeLength: 2.5
#
# Iteration: 26500, loss:0.12
# AverageReturn: -0.1000000387430191
# AverageEpisodeLength: 6.199999809265137
#
# Iteration: 27000, loss:0.11
# AverageReturn: 0.08999994397163391
# AverageEpisodeLength: 7.300000190734863
#
# Iteration: 27500, loss:0.10
# AverageReturn: -0.07000003010034561
# AverageEpisodeLength: 3.5
#
# Iteration: 28000, loss:0.14
# AverageReturn: -0.040000028908252716
# AverageEpisodeLength: 3.4000000953674316
#
# Iteration: 28500, loss:0.18
# AverageReturn: -0.32999998331069946
# AverageEpisodeLength: 4.800000190734863
#
# Iteration: 29000, loss:0.27
# AverageReturn: -0.030000019818544388
# AverageEpisodeLength: 2.5
#
# Iteration: 29500, loss:0.14
# AverageReturn: -0.33000004291534424
# AverageEpisodeLength: 3.5
#
# Iteration: 30000, loss:0.15
# AverageReturn: 0.8399999737739563
# AverageEpisodeLength: 4.699999809265137
#
# Iteration: 30500, loss:0.14
# AverageReturn: 0.049999967217445374
# AverageEpisodeLength: 4.400000095367432
#
# Iteration: 31000, loss:0.10
# AverageReturn: -0.010000035166740417
# AverageEpisodeLength: 3.299999952316284
#
# Iteration: 31500, loss:0.12
# AverageReturn: 2.2899999618530273
# AverageEpisodeLength: 6.699999809265137
#
# Iteration: 32000, loss:0.16
# AverageReturn: 2.3999998569488525
# AverageEpisodeLength: 7.199999809265137
#
# Iteration: 32500, loss:0.14
# AverageReturn: 0.3399999737739563
# AverageEpisodeLength: 4.300000190734863
#
# Iteration: 33000, loss:0.11
# AverageReturn: 1.0899999141693115
# AverageEpisodeLength: 5.599999904632568
#
# Iteration: 33500, loss:0.14
# AverageReturn: 1.3000000715255737
# AverageEpisodeLength: 3.5999999046325684
#
# Iteration: 34000, loss:0.17
# AverageReturn: 0.2799999713897705
# AverageEpisodeLength: 5.800000190734863
#
# Iteration: 34500, loss:0.12
# AverageReturn: 1.159999966621399
# AverageEpisodeLength: 5.800000190734863
#
# Iteration: 35000, loss:0.17
# AverageReturn: 1.0499999523162842
# AverageEpisodeLength: 7.900000095367432
#
# Iteration: 35500, loss:0.17
# AverageReturn: 1.8700001239776611
# AverageEpisodeLength: 4.199999809265137
#
# Iteration: 36000, loss:0.18
# AverageReturn: 2.429999828338623
# AverageEpisodeLength: 12.199999809265137
#
# Iteration: 36500, loss:0.19
# AverageReturn: 1.4800000190734863
# AverageEpisodeLength: 8.100000381469727
#
# Iteration: 37000, loss:0.10
# AverageReturn: 2.119999885559082
# AverageEpisodeLength: 6.400000095367432
#
# Iteration: 37500, loss:0.11
# AverageReturn: 1.1299998760223389
# AverageEpisodeLength: 5.900000095367432
#
# Iteration: 38000, loss:0.19
# AverageReturn: 1.3000000715255737
# AverageEpisodeLength: 4.900000095367432
#
# Iteration: 38500, loss:0.17
# AverageReturn: 3.2099997997283936
# AverageEpisodeLength: 8.300000190734863
#
# Iteration: 39000, loss:0.33
# AverageReturn: 2.9300003051757812
# AverageEpisodeLength: 6.199999809265137
#
# Iteration: 39500, loss:0.23
# AverageReturn: 6.919999599456787
# AverageEpisodeLength: 13.300000190734863
#
# Iteration: 40000, loss:0.24
# AverageReturn: 3.0299999713897705
# AverageEpisodeLength: 7.599999904632568
#
# Iteration: 40500, loss:0.33
# AverageReturn: 6.029999732971191
# AverageEpisodeLength: 7.699999809265137
#
# Iteration: 41000, loss:0.23
# AverageReturn: 3.9900002479553223
# AverageEpisodeLength: 6.900000095367432
#
# Iteration: 41500, loss:0.12
# AverageReturn: 4.78000020980835
# AverageEpisodeLength: 8.5
#
# Iteration: 42000, loss:0.33
# AverageReturn: 2.2799999713897705
# AverageEpisodeLength: 8.800000190734863
#
# Iteration: 42500, loss:0.22
# AverageReturn: 3.9700000286102295
# AverageEpisodeLength: 8.699999809265137
#
# Iteration: 43000, loss:0.14
# AverageReturn: 4.840000152587891
# AverageEpisodeLength: 8.300000190734863
#
# Iteration: 43500, loss:0.18
# AverageReturn: 4.920000076293945
# AverageEpisodeLength: 8.899999618530273
#
# Iteration: 44000, loss:0.46
# AverageReturn: 3.799999952316284
# AverageEpisodeLength: 9.699999809265137
#
# Iteration: 44500, loss:0.31
# AverageReturn: 3.4099998474121094
# AverageEpisodeLength: 5.900000095367432
#
# Iteration: 45000, loss:0.24
# AverageReturn: 5.710000038146973
# AverageEpisodeLength: 10.5
#
# Iteration: 45500, loss:0.27
# AverageReturn: 4.630000114440918
# AverageEpisodeLength: 10.300000190734863
#
# Iteration: 46000, loss:0.58
# AverageReturn: 1.2699997425079346
# AverageEpisodeLength: 11.300000190734863
#
# Iteration: 46500, loss:0.35
# AverageReturn: 2.059999465942383
# AverageEpisodeLength: 10.399999618530273
#
# Iteration: 47000, loss:0.32
# AverageReturn: 3.1500000953674316
# AverageEpisodeLength: 4.599999904632568
#
# Iteration: 47500, loss:0.27
# AverageReturn: 5.800000190734863
# AverageEpisodeLength: 8.899999618530273
#
# Iteration: 48000, loss:0.71
# AverageReturn: 0.9499999284744263
# AverageEpisodeLength: 3.9000000953674316
#
# Iteration: 48500, loss:0.59
# AverageReturn: 5.900000095367432
# AverageEpisodeLength: 9.0
#
# Iteration: 49000, loss:0.46
# AverageReturn: 4.599999904632568
# AverageEpisodeLength: 9.100000381469727
#
# Iteration: 49500, loss:0.45
# AverageReturn: 4.889999866485596
# AverageEpisodeLength: 7.699999809265137
#
# Iteration: 50000, loss:0.88
# AverageReturn: 7.859999656677246
# AverageEpisodeLength: 10.5
#
# Iteration: 50500, loss:0.47
# AverageReturn: 6.140000343322754
# AverageEpisodeLength: 12.0
#
# Iteration: 51000, loss:0.53
# AverageReturn: 4.199999809265137
# AverageEpisodeLength: 11.300000190734863
#
# Iteration: 51500, loss:0.55
# AverageReturn: 6.819999694824219
# AverageEpisodeLength: 9.300000190734863
#
# Iteration: 52000, loss:0.73
# AverageReturn: 5.329999923706055
# AverageEpisodeLength: 7.099999904632568
#
# Iteration: 52500, loss:0.71
# AverageReturn: 7.28000020980835
# AverageEpisodeLength: 8.199999809265137
#
# Iteration: 53000, loss:0.47
# AverageReturn: 8.530000686645508
# AverageEpisodeLength: 8.699999809265137
#
# Iteration: 53500, loss:0.63
# AverageReturn: 5.71999979019165
# AverageEpisodeLength: 8.399999618530273
#
# Iteration: 54000, loss:0.93
# AverageReturn: 7.410000801086426
# AverageEpisodeLength: 9.5
#
# Iteration: 54500, loss:0.48
# AverageReturn: 7.6700005531311035
# AverageEpisodeLength: 9.5
#
# Iteration: 55000, loss:0.34
# AverageReturn: 8.980000495910645
# AverageEpisodeLength: 9.800000190734863
#
# Iteration: 55500, loss:0.80
# AverageReturn: 7.84999942779541
# AverageEpisodeLength: 8.899999618530273
#
# Iteration: 56000, loss:0.60
# AverageReturn: 9.449999809265137
# AverageEpisodeLength: 11.600000381469727
#
# Iteration: 56500, loss:0.76
# AverageReturn: 10.289999961853027
# AverageEpisodeLength: 11.399999618530273
#
# Iteration: 57000, loss:0.69
# AverageReturn: 10.579999923706055
# AverageEpisodeLength: 11.300000190734863
#
# Iteration: 57500, loss:0.64
# AverageReturn: 10.829999923706055
# AverageEpisodeLength: 13.399999618530273
#
# Iteration: 58000, loss:0.53
# AverageReturn: 11.180000305175781
# AverageEpisodeLength: 11.800000190734863
#
# Iteration: 58500, loss:0.56
# AverageReturn: 9.039999008178711
# AverageEpisodeLength: 13.5
#
# Iteration: 59000, loss:0.82
# AverageReturn: 10.300000190734863
# AverageEpisodeLength: 11.800000190734863
#
# Iteration: 59500, loss:0.27
# AverageReturn: 9.159998893737793
# AverageEpisodeLength: 16.899999618530273
#
# Iteration: 60000, loss:0.46
# AverageReturn: 8.600000381469727
# AverageEpisodeLength: 10.300000190734863
#
# Iteration: 60500, loss:0.65
# AverageReturn: 7.979999542236328
# AverageEpisodeLength: 12.800000190734863
#
# Iteration: 61000, loss:0.44
# AverageReturn: 10.389999389648438
# AverageEpisodeLength: 12.800000190734863
#
# Iteration: 61500, loss:1.06
# AverageReturn: 11.579999923706055
# AverageEpisodeLength: 12.199999809265137
#
# Iteration: 62000, loss:0.66
# AverageReturn: 11.829999923706055
# AverageEpisodeLength: 11.800000190734863
#
# Iteration: 62500, loss:0.54
# AverageReturn: 11.230000495910645
# AverageEpisodeLength: 9.899999618530273
#
# Iteration: 63000, loss:0.60
# AverageReturn: 11.359999656677246
# AverageEpisodeLength: 9.899999618530273
#
# Iteration: 63500, loss:0.73
# AverageReturn: 3.6600069999694824
# AverageEpisodeLength: 32.20000076293945
#
# Iteration: 64000, loss:0.86
# AverageReturn: 11.260000228881836
# AverageEpisodeLength: 9.800000190734863
#
# Iteration: 64500, loss:0.73
# AverageReturn: 11.440000534057617
# AverageEpisodeLength: 9.199999809265137
#
# Iteration: 65000, loss:0.26
# AverageReturn: 11.5
# AverageEpisodeLength: 9.0
#
# Iteration: 65500, loss:0.43
# AverageReturn: 11.5
# AverageEpisodeLength: 9.0
#
# Iteration: 66000, loss:0.42
# AverageReturn: 10.34000015258789
# AverageEpisodeLength: 8.199999809265137
#
# Iteration: 66500, loss:0.48
# AverageReturn: 9.25999927520752
# AverageEpisodeLength: 17.0
#
# Iteration: 67000, loss:0.76
# AverageReturn: 11.649999618530273
# AverageEpisodeLength: 11.100000381469727
#
# Iteration: 67500, loss:0.52
# AverageReturn: 11.680000305175781
# AverageEpisodeLength: 11.0
#
# Iteration: 68000, loss:0.43
# AverageReturn: 11.819999694824219
# AverageEpisodeLength: 11.399999618530273
#
# Iteration: 68500, loss:0.48
# AverageReturn: 11.5
# AverageEpisodeLength: 9.0
#
# Iteration: 69000, loss:1.07
# AverageReturn: 11.5
# AverageEpisodeLength: 9.0
#
# Iteration: 69500, loss:0.64
# AverageReturn: 11.5
# AverageEpisodeLength: 9.0
#
# Iteration: 70000, loss:0.32
# AverageReturn: 11.5
# AverageEpisodeLength: 9.0
#
# Iteration: 70500, loss:0.59
# AverageReturn: 11.5
# AverageEpisodeLength: 9.0
#
# Iteration: 71000, loss:0.70
# AverageReturn: 11.5
# AverageEpisodeLength: 9.0
#
# Iteration: 71500, loss:0.62
# AverageReturn: 11.5
# AverageEpisodeLength: 9.0
#
# Iteration: 72000, loss:0.57
# AverageReturn: 11.489999771118164
# AverageEpisodeLength: 9.899999618530273
#
# Iteration: 72500, loss:0.79
# AverageReturn: 9.119999885559082
# AverageEpisodeLength: 12.800000190734863
#
# Iteration: 73000, loss:0.61
# AverageReturn: 9.519999504089355
# AverageEpisodeLength: 16.899999618530273
#
# Iteration: 73500, loss:0.29
# AverageReturn: 8.969999313354492
# AverageEpisodeLength: 12.0
#
# Iteration: 74000, loss:0.43
# AverageReturn: 6.6700005531311035
# AverageEpisodeLength: 21.399999618530273
#
# Iteration: 74500, loss:0.88
# AverageReturn: 10.59000015258789
# AverageEpisodeLength: 9.100000381469727
#
# Iteration: 75000, loss:0.76
# AverageReturn: 11.319999694824219
# AverageEpisodeLength: 9.600000381469727
#
# Iteration: 75500, loss:0.51
# AverageReturn: 10.410000801086426
# AverageEpisodeLength: 8.399999618530273
#
# Iteration: 76000, loss:0.69
# AverageReturn: 11.569999694824219
# AverageEpisodeLength: 9.199999809265137
#
# Iteration: 76500, loss:0.79
# AverageReturn: 1.1699950695037842
# AverageEpisodeLength: 39.29999923706055
#
# Iteration: 77000, loss:0.49
# AverageReturn: 3.110008716583252
# AverageEpisodeLength: 37.5
#
# Iteration: 77500, loss:0.63
# AverageReturn: 7.020000457763672
# AverageEpisodeLength: 18.5
#
# Iteration: 78000, loss:0.89
# AverageReturn: 6.380000114440918
# AverageEpisodeLength: 19.0
#
# Iteration: 78500, loss:0.55
# AverageReturn: 11.09999942779541
# AverageEpisodeLength: 15.100000381469727
#
# Iteration: 79000, loss:0.42
# AverageReturn: 10.9399995803833
# AverageEpisodeLength: 13.899999618530273
#
# Iteration: 79500, loss:0.70
# AverageReturn: 10.5
# AverageEpisodeLength: 12.0
#
# Iteration: 80000, loss:0.40
# AverageReturn: 9.039999961853027
# AverageEpisodeLength: 12.199999809265137
#
# Iteration: 80500, loss:0.60
# AverageReturn: 11.729999542236328
# AverageEpisodeLength: 13.0
#
# Iteration: 81000, loss:0.58
# AverageReturn: 11.789999008178711
# AverageEpisodeLength: 12.800000190734863
#
# Iteration: 81500, loss:0.82
# AverageReturn: 0.38996315002441406
# AverageEpisodeLength: 50.79999923706055
#
# Iteration: 82000, loss:0.54
# AverageReturn: 11.839999198913574
# AverageEpisodeLength: 12.199999809265137
#
# Iteration: 82500, loss:0.64
# AverageReturn: 10.389999389648438
# AverageEpisodeLength: 14.100000381469727
#
# Iteration: 83000, loss:0.51
# AverageReturn: 11.469999313354492
# AverageEpisodeLength: 14.300000190734863
#
# Iteration: 83500, loss:0.80
# AverageReturn: 11.779999732971191
# AverageEpisodeLength: 12.399999618530273
#
# Iteration: 84000, loss:0.65
# AverageReturn: 5.7900071144104
# AverageEpisodeLength: 32.79999923706055
#
# Iteration: 84500, loss:0.70
# AverageReturn: 9.210000991821289
# AverageEpisodeLength: 12.5
#
# Iteration: 85000, loss:0.86
# AverageReturn: 11.630000114440918
# AverageEpisodeLength: 14.199999809265137
#
# Iteration: 85500, loss:0.18
# AverageReturn: 5.390000343322754
# AverageEpisodeLength: 33.70000076293945
#
# Iteration: 86000, loss:0.83
# AverageReturn: 10.319999694824219
# AverageEpisodeLength: 12.600000381469727
#
# Iteration: 86500, loss:0.86
# AverageReturn: 10.969999313354492
# AverageEpisodeLength: 15.100000381469727
#
# Iteration: 87000, loss:0.41
# AverageReturn: 0.449972927570343
# AverageEpisodeLength: 46.79999923706055
#
# Iteration: 87500, loss:0.43
# AverageReturn: 7.669999122619629
# AverageEpisodeLength: 23.600000381469727
#
# Iteration: 88000, loss:0.47
# AverageReturn: 10.170000076293945
# AverageEpisodeLength: 19.5
#
# Iteration: 88500, loss:0.61
# AverageReturn: 10.219999313354492
# AverageEpisodeLength: 15.100000381469727
#
# Iteration: 89000, loss:0.44
# AverageReturn: 4.590003490447998
# AverageEpisodeLength: 30.5
#
# Iteration: 89500, loss:0.40
# AverageReturn: 1.7000091075897217
# AverageEpisodeLength: 39.70000076293945
#
# Iteration: 90000, loss:0.66
# AverageReturn: 11.670000076293945
# AverageEpisodeLength: 13.199999809265137
#
# Iteration: 90500, loss:0.44
# AverageReturn: -14.970026016235352
# AverageEpisodeLength: 100.80000305175781
#
# Iteration: 91000, loss:0.74
# AverageReturn: 12.140000343322754
# AverageEpisodeLength: 11.199999809265137
#
# Iteration: 91500, loss:0.17
# AverageReturn: 8.500003814697266
# AverageEpisodeLength: 24.200000762939453
#
# Iteration: 92000, loss:0.67
# AverageReturn: -1.869978904724121
# AverageEpisodeLength: 56.70000076293945
#
# Iteration: 92500, loss:1.12
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 93000, loss:0.66
# AverageReturn: 5.500000953674316
# AverageEpisodeLength: 17.700000762939453
#
# Iteration: 93500, loss:0.47
# AverageReturn: 10.25999927520752
# AverageEpisodeLength: 19.200000762939453
#
# Iteration: 94000, loss:0.65
# AverageReturn: 10.149999618530273
# AverageEpisodeLength: 18.700000762939453
#
# Iteration: 94500, loss:0.30
# AverageReturn: 8.379999160766602
# AverageEpisodeLength: 24.600000381469727
#
# Iteration: 95000, loss:0.84
# AverageReturn: 10.489999771118164
# AverageEpisodeLength: 16.700000762939453
#
# Iteration: 95500, loss:0.28
# AverageReturn: 8.050000190734863
# AverageEpisodeLength: 16.799999237060547
#
# Iteration: 96000, loss:0.91
# AverageReturn: 10.229999542236328
# AverageEpisodeLength: 14.199999809265137
#
# Iteration: 96500, loss:0.46
# AverageReturn: 8.949999809265137
# AverageEpisodeLength: 13.800000190734863
#
# Iteration: 97000, loss:0.76
# AverageReturn: 10.390000343322754
# AverageEpisodeLength: 8.899999618530273
#
# Iteration: 97500, loss:0.03
# AverageReturn: 9.389999389648438
# AverageEpisodeLength: 9.300000190734863
#
# Iteration: 98000, loss:0.18
# AverageReturn: 5.099998474121094
# AverageEpisodeLength: 23.700000762939453
#
# Iteration: 98500, loss:0.32
# AverageReturn: 10.649999618530273
# AverageEpisodeLength: 12.800000190734863
#
# Iteration: 99000, loss:0.16
# AverageReturn: 11.989999771118164
# AverageEpisodeLength: 11.699999809265137
#
# Iteration: 99500, loss:0.56
# AverageReturn: 9.899999618530273
# AverageEpisodeLength: 14.0
#
# Iteration: 100000, loss:0.36
# AverageReturn: 10.719999313354492
# AverageEpisodeLength: 11.699999809265137
#
# Iteration: 100500, loss:0.46
# AverageReturn: 11.480000495910645
# AverageEpisodeLength: 13.399999618530273
#
# Iteration: 101000, loss:0.20
# AverageReturn: 11.029999732971191
# AverageEpisodeLength: 11.100000381469727
#
# Iteration: 101500, loss:0.56
# AverageReturn: 9.60999870300293
# AverageEpisodeLength: 14.100000381469727
#
# Iteration: 102000, loss:0.55
# AverageReturn: 11.5600004196167
# AverageEpisodeLength: 12.699999809265137
#
# Iteration: 102500, loss:0.30
# AverageReturn: 9.760000228881836
# AverageEpisodeLength: 12.399999618530273
#
# Iteration: 103000, loss:1.21
# AverageReturn: 10.920000076293945
# AverageEpisodeLength: 11.899999618530273
#
# Iteration: 103500, loss:0.43
# AverageReturn: 1.1600061655044556
# AverageEpisodeLength: 33.900001525878906
#
# Iteration: 104000, loss:0.54
# AverageReturn: 7.5799994468688965
# AverageEpisodeLength: 13.699999809265137
#
# Iteration: 104500, loss:0.76
# AverageReturn: 12.069999694824219
# AverageEpisodeLength: 11.0
#
# Iteration: 105000, loss:0.81
# AverageReturn: 11.010000228881836
# AverageEpisodeLength: 10.300000190734863
#
# Iteration: 105500, loss:0.17
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 106000, loss:0.50
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 106500, loss:0.66
# AverageReturn: 10.779999732971191
# AverageEpisodeLength: 11.5
#
# Iteration: 107000, loss:0.57
# AverageReturn: 11.449999809265137
# AverageEpisodeLength: 13.5
#
# Iteration: 107500, loss:0.34
# AverageReturn: 11.719999313354492
# AverageEpisodeLength: 12.600000381469727
#
# Iteration: 108000, loss:1.04
# AverageReturn: 11.869999885559082
# AverageEpisodeLength: 12.100000381469727
#
# Iteration: 108500, loss:0.77
# AverageReturn: 11.440000534057617
# AverageEpisodeLength: 13.100000381469727
#
# Iteration: 109000, loss:0.43
# AverageReturn: 7.330000400543213
# AverageEpisodeLength: 17.899999618530273
#
# Iteration: 109500, loss:0.46
# AverageReturn: 10.969999313354492
# AverageEpisodeLength: 11.300000190734863
#
# Iteration: 110000, loss:0.29
# AverageReturn: 10.8100004196167
# AverageEpisodeLength: 10.100000381469727
#
# Iteration: 110500, loss:0.30
# AverageReturn: -10.440046310424805
# AverageEpisodeLength: 78.0
#
# Iteration: 111000, loss:0.65
# AverageReturn: -14.840179443359375
# AverageEpisodeLength: 95.5999984741211
#
# Iteration: 111500, loss:0.61
# AverageReturn: -44.90020751953125
# AverageEpisodeLength: 195.89999389648438
#
# Iteration: 112000, loss:0.20
# AverageReturn: -9.560052871704102
# AverageEpisodeLength: 74.19999694824219
#
# Iteration: 112500, loss:0.34
# AverageReturn: 10.949999809265137
# AverageEpisodeLength: 10.5
#
# Iteration: 113000, loss:0.67
# AverageReturn: 12.210000038146973
# AverageEpisodeLength: 11.399999618530273
#
# Iteration: 113500, loss:0.59
# AverageReturn: 11.09000015258789
# AverageEpisodeLength: 10.899999618530273
#
# Iteration: 114000, loss:0.65
# AverageReturn: 11.959999084472656
# AverageEpisodeLength: 11.800000190734863
#
# Iteration: 114500, loss:0.63
# AverageReturn: 12.25
# AverageEpisodeLength: 13.0
#
# Iteration: 115000, loss:0.04
# AverageReturn: 11.789999961853027
# AverageEpisodeLength: 12.800000190734863
#
# Iteration: 115500, loss:0.30
# AverageReturn: 11.839999198913574
# AverageEpisodeLength: 13.5
#
# Iteration: 116000, loss:0.73
# AverageReturn: 12.039999008178711
# AverageEpisodeLength: 12.399999618530273
#
# Iteration: 116500, loss:0.54
# AverageReturn: 12.149999618530273
# AverageEpisodeLength: 11.600000381469727
#
# Iteration: 117000, loss:0.52
# AverageReturn: 12.119999885559082
# AverageEpisodeLength: 11.699999809265137
#
# Iteration: 117500, loss:0.20
# AverageReturn: 12.050000190734863
# AverageEpisodeLength: 11.5
#
# Iteration: 118000, loss:0.18
# AverageReturn: 12.220000267028809
# AverageEpisodeLength: 11.800000190734863
#
# Iteration: 118500, loss:0.03
# AverageReturn: 11.769999504089355
# AverageEpisodeLength: 12.0
#
# Iteration: 119000, loss:0.30
# AverageReturn: 11.539999961853027
# AverageEpisodeLength: 10.600000381469727
#
# Iteration: 119500, loss:0.52
# AverageReturn: 11.899999618530273
# AverageEpisodeLength: 12.0
#
# Iteration: 120000, loss:0.30
# AverageReturn: 11.420000076293945
# AverageEpisodeLength: 12.300000190734863
#
# Iteration: 120500, loss:0.32
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 121000, loss:0.53
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 121500, loss:0.28
# AverageReturn: 10.980000495910645
# AverageEpisodeLength: 11.699999809265137
#
# Iteration: 122000, loss:0.18
# AverageReturn: 11.109999656677246
# AverageEpisodeLength: 10.399999618530273
#
# Iteration: 122500, loss:0.18
# AverageReturn: 12.089999198913574
# AverageEpisodeLength: 13.100000381469727
#
# Iteration: 123000, loss:0.57
# AverageReturn: 10.90999984741211
# AverageEpisodeLength: 11.5
#
# Iteration: 123500, loss:0.59
# AverageReturn: 11.910000801086426
# AverageEpisodeLength: 12.399999618530273
#
# Iteration: 124000, loss:0.41
# AverageReturn: 12.130000114440918
# AverageEpisodeLength: 12.100000381469727
#
# Iteration: 124500, loss:0.45
# AverageReturn: 11.880000114440918
# AverageEpisodeLength: 13.800000190734863
#
# Iteration: 125000, loss:0.29
# AverageReturn: 10.970000267028809
# AverageEpisodeLength: 10.0
#
# Iteration: 125500, loss:0.58
# AverageReturn: 12.079999923706055
# AverageEpisodeLength: 11.399999618530273
#
# Iteration: 126000, loss:0.97
# AverageReturn: 9.119999885559082
# AverageEpisodeLength: 12.800000190734863
#
# Iteration: 126500, loss:0.67
# AverageReturn: 11.929999351501465
# AverageEpisodeLength: 13.199999809265137
#
# Iteration: 127000, loss:0.48
# AverageReturn: 10.239999771118164
# AverageEpisodeLength: 14.600000381469727
#
# Iteration: 127500, loss:0.08
# AverageReturn: 10.84999942779541
# AverageEpisodeLength: 10.399999618530273
#
# Iteration: 128000, loss:0.46
# AverageReturn: 11.179999351501465
# AverageEpisodeLength: 10.600000381469727
#
# Iteration: 128500, loss:0.15
# AverageReturn: 10.960000038146973
# AverageEpisodeLength: 10.899999618530273
#
# Iteration: 129000, loss:0.58
# AverageReturn: 9.999999046325684
# AverageEpisodeLength: 14.100000381469727
#
# Iteration: 129500, loss:0.43
# AverageReturn: 12.079999923706055
# AverageEpisodeLength: 11.399999618530273
#
# Iteration: 130000, loss:0.43
# AverageReturn: 8.970000267028809
# AverageEpisodeLength: 10.800000190734863
#
# Iteration: 130500, loss:0.88
# AverageReturn: 11.429999351501465
# AverageEpisodeLength: 14.0
#
# Iteration: 131000, loss:0.46
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 12.300000190734863
#
# Iteration: 131500, loss:0.60
# AverageReturn: 10.969999313354492
# AverageEpisodeLength: 11.300000190734863
#
# Iteration: 132000, loss:0.47
# AverageReturn: 11.079999923706055
# AverageEpisodeLength: 10.5
#
# Iteration: 132500, loss:0.47
# AverageReturn: 9.889999389648438
# AverageEpisodeLength: 9.800000190734863
#
# Iteration: 133000, loss:0.40
# AverageReturn: 10.979999542236328
# AverageEpisodeLength: 10.399999618530273
#
# Iteration: 133500, loss:0.45
# AverageReturn: 10.870000839233398
# AverageEpisodeLength: 11.199999809265137
#
# Iteration: 134000, loss:1.13
# AverageReturn: 12.179999351501465
# AverageEpisodeLength: 11.5
#
# Iteration: 134500, loss:0.58
# AverageReturn: 12.330000877380371
# AverageEpisodeLength: 14.899999618530273
#
# Iteration: 135000, loss:0.67
# AverageReturn: 12.430000305175781
# AverageEpisodeLength: 13.699999809265137
#
# Iteration: 135500, loss:0.19
# AverageReturn: 10.879999160766602
# AverageEpisodeLength: 19.299999237060547
#
# Iteration: 136000, loss:0.18
# AverageReturn: 11.290000915527344
# AverageEpisodeLength: 13.699999809265137
#
# Iteration: 136500, loss:0.45
# AverageReturn: 12.569999694824219
# AverageEpisodeLength: 14.100000381469727
#
# Iteration: 137000, loss:0.68
# AverageReturn: 12.600000381469727
# AverageEpisodeLength: 14.0
#
# Iteration: 137500, loss:0.32
# AverageReturn: 12.360000610351562
# AverageEpisodeLength: 14.800000190734863
#
# Iteration: 138000, loss:0.30
# AverageReturn: 11.010000228881836
# AverageEpisodeLength: 14.199999809265137
#
# Iteration: 138500, loss:0.45
# AverageReturn: 12.369999885559082
# AverageEpisodeLength: 12.600000381469727
#
# Iteration: 139000, loss:0.30
# AverageReturn: 12.379999160766602
# AverageEpisodeLength: 13.0
#
# Iteration: 139500, loss:0.16
# AverageReturn: 12.279999732971191
# AverageEpisodeLength: 11.600000381469727
#
# Iteration: 140000, loss:0.35
# AverageReturn: 12.239999771118164
# AverageEpisodeLength: 11.300000190734863
#
# Iteration: 140500, loss:0.31
# AverageReturn: 12.230000495910645
# AverageEpisodeLength: 12.199999809265137
#
# Iteration: 141000, loss:0.73
# AverageReturn: 12.190000534057617
# AverageEpisodeLength: 13.199999809265137
#
# Iteration: 141500, loss:0.17
# AverageReturn: 11.309999465942383
# AverageEpisodeLength: 13.199999809265137
#
# Iteration: 142000, loss:0.44
# AverageReturn: 12.319999694824219
# AverageEpisodeLength: 11.899999618530273
#
# Iteration: 142500, loss:0.43
# AverageReturn: 12.319999694824219
# AverageEpisodeLength: 13.199999809265137
#
# Iteration: 143000, loss:0.17
# AverageReturn: 12.280000686645508
# AverageEpisodeLength: 12.899999618530273
#
# Iteration: 143500, loss:0.29
# AverageReturn: 12.40999984741211
# AverageEpisodeLength: 12.899999618530273
#
# Iteration: 144000, loss:0.48
# AverageReturn: 12.299999237060547
# AverageEpisodeLength: 12.399999618530273
#
# Iteration: 144500, loss:0.85
# AverageReturn: 12.380000114440918
# AverageEpisodeLength: 14.300000190734863
#
# Iteration: 145000, loss:0.31
# AverageReturn: 12.5
# AverageEpisodeLength: 13.899999618530273
#
# Iteration: 145500, loss:0.16
# AverageReturn: 11.449999809265137
# AverageEpisodeLength: 13.600000381469727
#
# Iteration: 146000, loss:0.66
# AverageReturn: 11.199999809265137
# AverageEpisodeLength: 12.699999809265137
#
# Iteration: 146500, loss:0.22
# AverageReturn: 11.059999465942383
# AverageEpisodeLength: 11.0
#
# Iteration: 147000, loss:0.17
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 147500, loss:0.22
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 148000, loss:0.27
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 11.0
#
# Iteration: 148500, loss:0.51
# AverageReturn: 12.360000610351562
# AverageEpisodeLength: 14.800000190734863
#
# Iteration: 149000, loss:0.29
# AverageReturn: 12.510000228881836
# AverageEpisodeLength: 14.300000190734863
#
# Iteration: 149500, loss:0.16
# AverageReturn: 11.15000057220459
# AverageEpisodeLength: 13.300000190734863

# %%
avg_return_trained = column(all_metrics,0)
avg_ep_trained = column(all_metrics,1)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,15))

axs[0].plot(range(len(avg_return_trained)), avg_return_trained)
axs[0].set_title('Average Return')

axs[1].plot(range(len(avg_ep_trained)), avg_ep_trained, 'tab:orange')
axs[1].set_title('Average Episode Length')

for ax in axs.flat:
    ax.set(xlabel='Number of Iterations', ylabel='Metric Value')

# %% [markdown]
# ### Evaluate

# %%
def compute_avg_return(environment, policy, num_episodes=10):

    total_return = 0.0
    
    for _ in range(num_episodes):
        time_step = environment.reset()
        episode_return = 0.0
        
        while not time_step.is_last():
            action_step = policy.action(time_step)
            time_step = environment.step(action_step.action)
            episode_return += time_step.reward
        
        total_return += episode_return

    avg_return = total_return / num_episodes
    
    return avg_return.numpy()[0]

# %%
# Reset the train step
agent.train_step_counter.assign(0)

#reset eval environment
eval_env.reset()

# Evaluate the agent's policy once before training.
avg_return = compute_avg_return(eval_env, agent.policy, 5)

# %%
avg_return
# Out:
# 12.6

# %% [markdown]
# ### Visualize Episode

# %%
def observation_viz(observation):
    numpy_obs = observation.numpy()[0]
    string_obs = np.array(np.reshape(numpy_obs, (-1, 6)), dtype=np.unicode_)
    if string_obs[5][5] != "1":
      string_obs[5][5] = "❌"
    string_obs = np.where(string_obs=="1","🐕", string_obs) 
    string_obs = np.where(string_obs=="2","👮", string_obs)
    string_obs = np.where(string_obs=="3","🦴", string_obs)
    string_obs = np.where(string_obs=="0","⬚", string_obs)
    observe_2d = pd.DataFrame(string_obs)
    observe_2d.columns = [''] * len(observe_2d.columns)
    observe_2d = observe_2d.to_string(index=False)
    print("\n{}\n".format(observe_2d))

# %%
def compute_viz(environment, policy, num_episodes=10):

    total_return = 0.0
    
    for _ in range(num_episodes):
        time_step = environment.reset()
        episode_return = 0.0
        step = 0
        print("Step: 0")
        observation_viz(time_step.observation)
        while not time_step.is_last():
            step += 1
            print("---\nStep: {}".format(step))
            action_step = policy.action(time_step)
            print("Action taken: {}".format(action_step.action))
            time_step = environment.step(action_step.action)
            observation_viz(time_step.observation)
            episode_return += time_step.reward
            print("Reward: {} \n".format(episode_return))
        
        total_return += episode_return

    avg_return = total_return / num_episodes
    
    return avg_return.numpy()[0]

# %%
# Reset the train step
agent.train_step_counter.assign(0)

#reset eval environment
eval_env.reset()

# Evaluate the agent's policy once before training.
avg_return = compute_viz(eval_env, agent.policy, 1)
# Out:
# Step: 0
#
#
#  🐕  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  🦴  ⬚  🦴  👮  ⬚
#  ⬚  ⬚  👮  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  👮  ⬚  ❌
#
# ---
# Step: 1
# Action taken: [1]
#
#
#  ⬚  🐕  ⬚  ⬚  ⬚  🦴
#  👮  🦴  ⬚  🦴  👮  ⬚
#  ⬚  ⬚  👮  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  👮  ⬚  ❌
#
# Reward: [-0.3]
#
# ---
# Step: 2
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  🐕  ⬚  🦴  👮  ⬚
#  ⬚  ⬚  👮  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  👮  ⬚  ❌
#
# Reward: [0.7]
#
# ---
# Step: 3
# Action taken: [1]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  ⬚  🐕  🦴  👮  ⬚
#  ⬚  ⬚  👮  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  👮  ⬚  ❌
#
# Reward: [0.39999998]
#
# ---
# Step: 4
# Action taken: [1]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  ⬚  ⬚  🐕  👮  ⬚
#  ⬚  ⬚  👮  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  👮  ⬚  ❌
#
# Reward: [1.4]
#
# ---
# Step: 5
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  ⬚  ⬚  ⬚  👮  ⬚
#  ⬚  ⬚  👮  🐕  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  👮  ⬚  ❌
#
# Reward: [1.0999999]
#
# ---
# Step: 6
# Action taken: [1]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  ⬚  ⬚  ⬚  👮  ⬚
#  ⬚  ⬚  👮  ⬚  🐕  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  👮  ⬚  ❌
#
# Reward: [2.1]
#
# ---
# Step: 7
# Action taken: [1]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  ⬚  ⬚  ⬚  👮  ⬚
#  ⬚  ⬚  👮  ⬚  ⬚  🐕
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  👮  ⬚  ❌
#
# Reward: [1.8]
#
# ---
# Step: 8
# Action taken: [1]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  ⬚  ⬚  ⬚  👮  ⬚
#  ⬚  ⬚  👮  ⬚  ⬚  ⬚
#  🐕  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  👮  ⬚  ❌
#
# Reward: [1.5]
#
# ---
# Step: 9
# Action taken: [1]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  ⬚  ⬚  ⬚  👮  ⬚
#  ⬚  ⬚  👮  ⬚  ⬚  ⬚
#  ⬚  🐕  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  👮  ⬚  ❌
#
# Reward: [2.5]
#
# ---
# Step: 10
# Action taken: [0]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  ⬚  ⬚  ⬚  👮  ⬚
#  ⬚  ⬚  👮  ⬚  ⬚  ⬚
#  🐕  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  👮  ⬚  ❌
#
# Reward: [2.2]
#
# ---
# Step: 11
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  ⬚  ⬚  ⬚  👮  ⬚
#  ⬚  ⬚  👮  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  🐕  👮  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  👮  ⬚  ❌
#
# Reward: [1.9000001]
#
# ---
# Step: 12
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  ⬚  ⬚  ⬚  👮  ⬚
#  ⬚  ⬚  👮  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  ⬚
#  🐕  ⬚  ⬚  👮  ⬚  ❌
#
# Reward: [2.9]
#
# ---
# Step: 13
# Action taken: [0]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  ⬚  ⬚  ⬚  👮  ⬚
#  ⬚  ⬚  👮  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  🐕
#  ⬚  ⬚  ⬚  👮  ⬚  ❌
#
# Reward: [2.6000001]
#
# ---
# Step: 14
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  👮  ⬚  ⬚  ⬚  👮  ⬚
#  ⬚  ⬚  👮  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  👮  🦴  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  👮  ⬚  🐕
#
# Reward: [12.6]

# %% [markdown]
# ### Saving/Loading the Agent

# %%
from datetime import datetime

# %%
folder_name = datetime.now().timestamp()
folder_name = "/content/saved_agents/"+str(folder_name)

# %% [markdown]
# #### Saving the agent

# %%
tf.saved_model.save(agent, folder_name)
# Out:
# INFO:tensorflow:Assets written to: /content/saved_agents/1590937968.715281/assets

# %%
# !zip -r saved_agent.zip /content/saved_agents/1590937968.715281/
# Out:
#   adding: content/saved_agents/1590937968.715281/ (stored 0%)
#   adding: content/saved_agents/1590937968.715281/variables/ (stored 0%)
#   adding: content/saved_agents/1590937968.715281/variables/variables.index (deflated 66%)
#   adding: content/saved_agents/1590937968.715281/variables/variables.data-00000-of-00001 (deflated 13%)
#   adding: content/saved_agents/1590937968.715281/saved_model.pb (deflated 89%)
#   adding: content/saved_agents/1590937968.715281/assets/ (stored 0%)

# %% [markdown]
# #### Loading the agent

# %%
loaded_agent = tf.saved_model.load(folder_name)

# %% [markdown]
# #### Saving the policy

# %%
agent_policy = agent.policy

# %%
policy_timestamp = datetime.now().timestamp()
policy_saver.PolicySaver(agent_policy).save('/content/saved_agents/policy_'+str(policy_timestamp))
# Out:
# INFO:tensorflow:Assets written to: /content/saved_agents/policy_1590939541.184466/assets

# %%
# !zip -r saved_policy.zip /content/saved_agents/policy_1590939541.184466/
# Out:
#   adding: content/saved_agents/policy_1590939541.184466/ (stored 0%)
#   adding: content/saved_agents/policy_1590939541.184466/variables/ (stored 0%)
#   adding: content/saved_agents/policy_1590939541.184466/variables/variables.index (deflated 44%)
#   adding: content/saved_agents/policy_1590939541.184466/variables/variables.data-00000-of-00001 (deflated 12%)
#   adding: content/saved_agents/policy_1590939541.184466/saved_model.pb (deflated 85%)
#   adding: content/saved_agents/policy_1590939541.184466/assets/ (stored 0%)

# %% [markdown]
# #### Loading the policy

# %%
loaded_policy = tf.saved_model.load("/content/saved_agents/policy_1590939541.184466/")

# %%
eval_timestep = eval_env.reset()
loaded_action = loaded_policy.action(eval_timestep)
print(loaded_action)
# Out:
# PolicyStep(action=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>, state=(), info=())
