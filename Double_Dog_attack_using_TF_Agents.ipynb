# %% [markdown]
# # Double Dog Attack (DDA) using TF-Agents

# %%
# !pip install tf-agents
# Out:
# Collecting tf-agents
#   Downloading https://files.pythonhosted.org/packages/ef/b0/88c9aab39050cfb544ec73ee48b8d0e67b4b16ed5470c82235255b119952/tf_agents-0.5.0-py3-none-any.whl (933kB)
#      |████████████████████████████████| 942kB 4.5MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tf-agents) (1.12.0)
# Collecting gin-config==0.1.3
#   Downloading https://files.pythonhosted.org/packages/8c/be/c984b1c8a7ba1c385b32bf39c7a225cd9f713d49705898309d01b60fd0e7/gin_config-0.1.3-py3-none-any.whl (43kB)
#      |████████████████████████████████| 51kB 7.1MB/s
# Requirement already satisfied: absl-py>=0.6.1 in /usr/local/lib/python3.6/dist-packages (from tf-agents) (0.9.0)
# Collecting protobuf>=3.11.3
#   Downloading https://files.pythonhosted.org/packages/28/05/9867ef8eafd12265267bee138fa2c46ebf34a276ea4cbe184cba4c606e8b/protobuf-3.12.2-cp36-cp36m-manylinux1_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 12.8MB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tf-agents) (1.18.4)
# Requirement already satisfied: tensorflow-probability>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from tf-agents) (0.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.11.3->tf-agents) (47.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from tensorflow-probability>=0.9.0->tf-agents) (4.4.2)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-probability>=0.9.0->tf-agents) (0.3.3)
# Requirement already satisfied: cloudpickle>=1.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-probability>=0.9.0->tf-agents) (1.3.0)
# Installing collected packages: gin-config, protobuf, tf-agents
#   Found existing installation: gin-config 0.3.0
#     Uninstalling gin-config-0.3.0:
#       Successfully uninstalled gin-config-0.3.0
#   Found existing installation: protobuf 3.10.0
#     Uninstalling protobuf-3.10.0:
#       Successfully uninstalled protobuf-3.10.0
# Successfully installed gin-config-0.1.3 protobuf-3.12.2 tf-agents-0.5.0

# %% [markdown]
# ### Imports

# %%
from enum import Enum
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tf_agents.environments import py_environment
from tf_agents.environments import tf_environment
from tf_agents.environments import tf_py_environment
from tf_agents.environments import utils
from tf_agents.specs import array_spec
from tf_agents.trajectories import time_step as timeStep

from tf_agents.policies import random_tf_policy

from tf_agents.metrics import tf_py_metric
from tf_agents.metrics import tf_metrics
from tf_agents.metrics import py_metric
from tf_agents.drivers import py_driver
from tf_agents.drivers import dynamic_episode_driver

from tf_agents.agents.dqn import dqn_agent
from tf_agents.drivers import dynamic_step_driver
from tf_agents.networks import q_network
from tf_agents.replay_buffers import tf_uniform_replay_buffer

from tf_agents.policies import random_tf_policy
from tf_agents.trajectories import trajectory
from tf_agents.utils import common

from tf_agents.policies import policy_saver

# %%
def column(matrix, i):
    return [row[i] for row in matrix]

# %% [markdown]
# ### Game Environment

# %%
class ActionResult(Enum):
    VALID_MOVE = 1
    ILLEGAL_MOVE = 2
    FOUND_BONE = 3
    FOUND_ROBOT = 4
    GAME_COMPLETE = 5
    SNEAK_ATTACK = 6

# %%
class DogAdventure():
    def __init__(self):
        self._state = np.zeros((36,),dtype=np.int32)
        self._robot_locations = [10,14,25,28]
        self._bone_locations = [5,7,9,16,19,26,30]
        self._state[self._robot_locations] = 2
        self._state[self._bone_locations] = 3
        self._state[0] = 1
        self._state[1] = 4
        self._game_ended = False

    def reset(self):
        self._state = np.zeros((36,),dtype=np.int32)
        self._state[self._robot_locations] = 2
        self._state[self._bone_locations] = 3
        self._state[0] = 1
        self._state[1] = 4
        self._game_ended = False

    def __is_spot_last(self, position):
        return position == 35

    def move_dog(self, current_position, next_position, attack, player):

        if self.__is_spot_last(next_position):
          if player == 2:
            return ActionResult.ILLEGAL_MOVE
          else:
            self._state[current_position] = 0
            self._state[next_position] = 1

            self._game_ended = True
            return ActionResult.GAME_COMPLETE
        
        if next_position < 0 or next_position > (len(self._state) - 1):
          return ActionResult.ILLEGAL_MOVE

        if self._state[next_position] == 1 or self._state[next_position] == 4:
          return ActionResult.ILLEGAL_MOVE

        if self._state[next_position] == 2:
          if attack:
            if player == 2:
              self._state[current_position] = 0
              self._state[next_position] = 4
              return ActionResult.SNEAK_ATTACK
            else:
              self._state[current_position] = 0
              self._state[next_position] = 1
              return ActionResult.SNEAK_ATTACK
          else:
            self._game_ended = True
            return ActionResult.FOUND_ROBOT

        if self._state[next_position] == 3:
          if attack:
            return ActionResult.ILLEGAL_MOVE
          else:
            if player == 2:
              self._state[current_position] = 0
              self._state[next_position] = 4
              return ActionResult.FOUND_BONE
            else:
              self._state[current_position] = 0
              self._state[next_position] = 1
              return ActionResult.FOUND_BONE

        if self._state[next_position] == 0 and attack:
          return ActionResult.ILLEGAL_MOVE
          
        if player == 2:
          self._state[current_position] = 0
          self._state[next_position] = 4
          return ActionResult.VALID_MOVE
        
        self._state[current_position] = 0
        self._state[next_position] = 1
        return ActionResult.VALID_MOVE

    def game_ended(self):
        return self._game_ended
  
    def game_state(self):
        return self._state

# %%
class DogAdventureEnvironment(py_environment.PyEnvironment):

    def __init__(self, game):
        self._action_spec = array_spec.BoundedArraySpec(
            shape=(), dtype=np.int32, minimum=0, maximum=15, name='action')
        self._observation_spec = array_spec.BoundedArraySpec(
            shape=(36,), dtype=np.int32, minimum=0, maximum=4, name='observation')

        # 0=>Left, 1=>Right, 2=>Down, 3=>Up 
        # 4=>attack_up_right, 5=>attack_up_left, 6=>attack_down_right, 7=>attack_down_left
        # same order for player 2, index 8 and onwards
        self._action_values = {0:-1,1:1,2:-6,3:6,4:7,5:5,6:-7,7:-5,8:-1,9:1,10:-6,11:6,12:7,13:5,14:-7,15:-5}
        self._game = game

    def action_spec(self):
        return self._action_spec

    def observation_spec(self):
        return self._observation_spec

    def _reset(self):
        self._game.reset()
        return timeStep.restart(self._game.game_state())
  
    def _step(self, action):    

        if self._game.game_ended():
            return self.reset()

        action = action.item()
        attack = False
        player = 1

        if 4 <= action <= 7 or 12 <= action <= 15:
          attack = True

        if 8 <= action <= 15:
          player = 2

        next_agent_position_direction = self._action_values.get(action)
        
        if player == 2:
          current_agent_position = np.where(self._game.game_state() == 4)[0].item()
        else:
          current_agent_position = np.where(self._game.game_state() == 1)[0].item()

        new_agent_position = current_agent_position + next_agent_position_direction
        response = self._game.move_dog(current_agent_position,new_agent_position, attack, player)

        if response == ActionResult.GAME_COMPLETE:
            return timeStep.termination(self._game.game_state(), 10)

        elif response == ActionResult.ILLEGAL_MOVE:
            return timeStep.transition(self._game.game_state(), reward=-0.5, discount=1.0)

        elif response == ActionResult.FOUND_ROBOT:
            return timeStep.termination(self._game.game_state(), -0.8)
        
        elif response == ActionResult.SNEAK_ATTACK:
            return timeStep.transition(self._game.game_state(), reward=2, discount=1.0)

        elif response == ActionResult.FOUND_BONE:
            return timeStep.transition(self._game.game_state(), reward=1, discount=1.0)

        return timeStep.transition(self._game.game_state(), reward=-0.3, discount=1.0)

# %%
dogEnvironemt = DogAdventureEnvironment(DogAdventure())
utils.validate_py_environment(dogEnvironemt, episodes=5)

# %%
train_env = tf_py_environment.TFPyEnvironment(dogEnvironemt)
eval_env = tf_py_environment.TFPyEnvironment(dogEnvironemt)

# %% [markdown]
# ### DQN Setup

# %%
fc_layer_params = [32,64]

q_net = q_network.QNetwork(
            train_env.observation_spec(),
            train_env.action_spec(),
            fc_layer_params = fc_layer_params
        )

train_step = tf.Variable(0)
update_period = 2
optimizer = tf.keras.optimizers.Adam(lr=2.5e-3, epsilon=0.001)

epsilon_fn = tf.keras.optimizers.schedules.PolynomialDecay(
                initial_learning_rate=1.0, 
                decay_steps=250000 // update_period,
                end_learning_rate=0.01)

agent = dqn_agent.DdqnAgent(
        train_env.time_step_spec(),
        train_env.action_spec(),
        q_network=q_net,
        optimizer=optimizer,
        target_update_period=2000,
        td_errors_loss_fn=tf.keras.losses.Huber(reduction="none"),
        gamma=0.99,
        train_step_counter=train_step,
        epsilon_greedy=lambda: epsilon_fn(train_step))

agent.initialize()

# %% [markdown]
# ### Replay Buffer Setup

# %%
replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
    data_spec=agent.collect_data_spec,
    batch_size=train_env.batch_size,
    max_length=1000000)

replay_buffer_observer = replay_buffer.add_batch

# %% [markdown]
# ### Metrics Setup

# %%
train_metrics = [tf_metrics.AverageReturnMetric(), tf_metrics.AverageEpisodeLengthMetric()]

# %% [markdown]
# ### Driver Setup

# %%
collect_driver = dynamic_step_driver.DynamicStepDriver(
    train_env,
    agent.collect_policy,
    observers=[replay_buffer_observer] + train_metrics,
    num_steps=7)

# %% [markdown]
# ### Collect trajectories using Random Policy

# %%
class ShowProgress:
    def __init__(self, total):
        self.counter = 0
        self.total = total
    def __call__(self, trajectory):
        if not trajectory.is_boundary():
            self.counter += 1
        if self.counter % 100 == 0:
            print("\r{}/{}".format(self.counter, self.total), end="")

# %%
initial_collect_policy = random_tf_policy.RandomTFPolicy(train_env.time_step_spec(), train_env.action_spec())

init_driver = dynamic_step_driver.DynamicStepDriver(
    train_env,
    initial_collect_policy,
    observers=[replay_buffer.add_batch, ShowProgress(35000)],
    num_steps=35000)

final_time_step, final_policy_state = init_driver.run()
# Out:
# 35000/35000

# %% [markdown]
# ### Verify collected trajectories

# %%
trajectories, buffer_info = replay_buffer.get_next(sample_batch_size=2, num_steps=10)

# %%
trajectories._fields
# Out:
# ('step_type',
#  'observation',
#  'action',
#  'policy_info',
#  'next_step_type',
#  'reward',
#  'discount')

# %%
time_steps, action_steps, next_time_steps = trajectory.to_transition(trajectories)
time_steps.observation.shape
# Out:
# TensorShape([2, 9, 36])

# %% [markdown]
# ### Create Dataset from Replay Buffer

# %%
dataset = replay_buffer.as_dataset(sample_batch_size=200, num_steps=2, num_parallel_calls=3).prefetch(3)

# %% [markdown]
# ### Run it under common function to make it faster

# %%
collect_driver.run = common.function(collect_driver.run)
agent.train = common.function(agent.train)

# %% [markdown]
# ### Train

# %%
all_train_loss = []
all_metrics = []

# %%
def train_agent(n_iterations):
    time_step = None
    policy_state = agent.collect_policy.get_initial_state(train_env.batch_size)
    iterator = iter(dataset)
    
    for iteration in range(n_iterations):
        current_metrics = []
        
        time_step, policy_state = collect_driver.run(time_step, policy_state)
        trajectories, buffer_info = next(iterator)
        
        train_loss = agent.train(trajectories)
        all_train_loss.append(train_loss.loss.numpy())

        for i in range(len(train_metrics)):
            current_metrics.append(train_metrics[i].result().numpy())
            
        all_metrics.append(current_metrics)
        
        if iteration % 500 == 0:
            print("\nIteration: {}, loss:{:.2f}".format(iteration, train_loss.loss.numpy()))
            
            for i in range(len(train_metrics)):
                print('{}: {}'.format(train_metrics[i].name, train_metrics[i].result().numpy()))

# %%
train_agent(150000)
# Out:
# Iteration: 0, loss:0.17
# AverageReturn: 0.0
# AverageEpisodeLength: 0.0
#
# Iteration: 500, loss:0.05
# AverageReturn: -28.93001937866211
# AverageEpisodeLength: 88.30000305175781
#
# Iteration: 1000, loss:0.11
# AverageReturn: -20.84000015258789
# AverageEpisodeLength: 69.0
#
# Iteration: 1500, loss:0.04
# AverageReturn: -37.97002410888672
# AverageEpisodeLength: 120.80000305175781
#
# Iteration: 2000, loss:0.19
# AverageReturn: -22.409992218017578
# AverageEpisodeLength: 70.0
#
# Iteration: 2500, loss:0.05
# AverageReturn: -18.669994354248047
# AverageEpisodeLength: 57.70000076293945
#
# Iteration: 3000, loss:0.14
# AverageReturn: -15.639996528625488
# AverageEpisodeLength: 47.599998474121094
#
# Iteration: 3500, loss:0.07
# AverageReturn: -61.650108337402344
# AverageEpisodeLength: 178.0
#
# Iteration: 4000, loss:0.41
# AverageReturn: -63.78993606567383
# AverageEpisodeLength: 171.8000030517578
#
# Iteration: 4500, loss:0.06
# AverageReturn: -61.1699333190918
# AverageEpisodeLength: 176.39999389648438
#
# Iteration: 5000, loss:0.06
# AverageReturn: -11.289996147155762
# AverageEpisodeLength: 40.900001525878906
#
# Iteration: 5500, loss:0.04
# AverageReturn: -36.27003860473633
# AverageEpisodeLength: 106.69999694824219
#
# Iteration: 6000, loss:0.18
# AverageReturn: -53.9898681640625
# AverageEpisodeLength: 151.89999389648438
#
# Iteration: 6500, loss:0.11
# AverageReturn: -63.4200325012207
# AverageEpisodeLength: 185.39999389648438
#
# Iteration: 7000, loss:0.10
# AverageReturn: -81.46992492675781
# AverageEpisodeLength: 239.1999969482422
#
# Iteration: 7500, loss:0.05
# AverageReturn: -79.72982788085938
# AverageEpisodeLength: 217.89999389648438
#
# Iteration: 8000, loss:0.20
# AverageReturn: -17.71000099182129
# AverageEpisodeLength: 63.5
#
# Iteration: 8500, loss:0.08
# AverageReturn: -27.740020751953125
# AverageEpisodeLength: 87.5999984741211
#
# Iteration: 9000, loss:0.14
# AverageReturn: -15.719995498657227
# AverageEpisodeLength: 54.400001525878906
#
# Iteration: 9500, loss:0.14
# AverageReturn: -20.06999397277832
# AverageEpisodeLength: 73.4000015258789
#
# Iteration: 10000, loss:0.19
# AverageReturn: -20.479995727539062
# AverageEpisodeLength: 70.19999694824219
#
# Iteration: 10500, loss:0.16
# AverageReturn: -18.069995880126953
# AverageEpisodeLength: 61.70000076293945
#
# Iteration: 11000, loss:0.08
# AverageReturn: -16.45999526977539
# AverageEpisodeLength: 57.5
#
# Iteration: 11500, loss:0.06
# AverageReturn: -21.990013122558594
# AverageEpisodeLength: 79.0999984741211
#
# Iteration: 12000, loss:0.10
# AverageReturn: -37.1400032043457
# AverageEpisodeLength: 121.69999694824219
#
# Iteration: 12500, loss:0.08
# AverageReturn: -13.269994735717773
# AverageEpisodeLength: 47.599998474121094
#
# Iteration: 13000, loss:0.07
# AverageReturn: -28.39005470275879
# AverageEpisodeLength: 88.69999694824219
#
# Iteration: 13500, loss:0.13
# AverageReturn: -28.300039291381836
# AverageEpisodeLength: 95.5999984741211
#
# Iteration: 14000, loss:0.12
# AverageReturn: -19.530010223388672
# AverageEpisodeLength: 75.30000305175781
#
# Iteration: 14500, loss:0.08
# AverageReturn: -20.679990768432617
# AverageEpisodeLength: 80.30000305175781
#
# Iteration: 15000, loss:0.12
# AverageReturn: -21.34001350402832
# AverageEpisodeLength: 77.30000305175781
#
# Iteration: 15500, loss:0.05
# AverageReturn: -6.040000915527344
# AverageEpisodeLength: 29.200000762939453
#
# Iteration: 16000, loss:0.15
# AverageReturn: -8.779997825622559
# AverageEpisodeLength: 40.900001525878906
#
# Iteration: 16500, loss:0.08
# AverageReturn: -21.27001953125
# AverageEpisodeLength: 81.30000305175781
#
# Iteration: 17000, loss:0.11
# AverageReturn: -22.29001235961914
# AverageEpisodeLength: 75.5
#
# Iteration: 17500, loss:0.08
# AverageReturn: -27.590007781982422
# AverageEpisodeLength: 109.9000015258789
#
# Iteration: 18000, loss:0.08
# AverageReturn: -36.31006622314453
# AverageEpisodeLength: 114.69999694824219
#
# Iteration: 18500, loss:0.06
# AverageReturn: -33.4000358581543
# AverageEpisodeLength: 123.0
#
# Iteration: 19000, loss:0.06
# AverageReturn: -30.380029678344727
# AverageEpisodeLength: 117.69999694824219
#
# Iteration: 19500, loss:0.03
# AverageReturn: -28.850032806396484
# AverageEpisodeLength: 113.5
#
# Iteration: 20000, loss:0.15
# AverageReturn: -29.340017318725586
# AverageEpisodeLength: 119.5999984741211
#
# Iteration: 20500, loss:0.04
# AverageReturn: -22.310022354125977
# AverageEpisodeLength: 86.0
#
# Iteration: 21000, loss:0.05
# AverageReturn: -32.5900764465332
# AverageEpisodeLength: 118.0999984741211
#
# Iteration: 21500, loss:0.10
# AverageReturn: -27.310073852539062
# AverageEpisodeLength: 96.9000015258789
#
# Iteration: 22000, loss:0.21
# AverageReturn: -12.79999828338623
# AverageEpisodeLength: 60.599998474121094
#
# Iteration: 22500, loss:0.16
# AverageReturn: -29.040014266967773
# AverageEpisodeLength: 114.30000305175781
#
# Iteration: 23000, loss:0.06
# AverageReturn: -19.869991302490234
# AverageEpisodeLength: 74.4000015258789
#
# Iteration: 23500, loss:0.06
# AverageReturn: -33.72004699707031
# AverageEpisodeLength: 116.80000305175781
#
# Iteration: 24000, loss:0.08
# AverageReturn: -19.410015106201172
# AverageEpisodeLength: 76.80000305175781
#
# Iteration: 24500, loss:0.08
# AverageReturn: -36.61002731323242
# AverageEpisodeLength: 133.8000030517578
#
# Iteration: 25000, loss:0.12
# AverageReturn: -27.370019912719727
# AverageEpisodeLength: 114.69999694824219
#
# Iteration: 25500, loss:0.05
# AverageReturn: -17.3599910736084
# AverageEpisodeLength: 72.69999694824219
#
# Iteration: 26000, loss:0.11
# AverageReturn: -15.349992752075195
# AverageEpisodeLength: 76.80000305175781
#
# Iteration: 26500, loss:0.15
# AverageReturn: -6.690001487731934
# AverageEpisodeLength: 39.29999923706055
#
# Iteration: 27000, loss:0.12
# AverageReturn: -13.079994201660156
# AverageEpisodeLength: 66.19999694824219
#
# Iteration: 27500, loss:0.20
# AverageReturn: -13.72999382019043
# AverageEpisodeLength: 70.4000015258789
#
# Iteration: 28000, loss:0.18
# AverageReturn: -12.089996337890625
# AverageEpisodeLength: 61.599998474121094
#
# Iteration: 28500, loss:0.14
# AverageReturn: -20.949987411499023
# AverageEpisodeLength: 103.0999984741211
#
# Iteration: 29000, loss:0.05
# AverageReturn: -18.09001350402832
# AverageEpisodeLength: 76.9000015258789
#
# Iteration: 29500, loss:0.06
# AverageReturn: -16.76999282836914
# AverageEpisodeLength: 88.4000015258789
#
# Iteration: 30000, loss:0.19
# AverageReturn: -25.029987335205078
# AverageEpisodeLength: 111.30000305175781
#
# Iteration: 30500, loss:0.04
# AverageReturn: -22.349994659423828
# AverageEpisodeLength: 100.5999984741211
#
# Iteration: 31000, loss:0.21
# AverageReturn: -10.80999755859375
# AverageEpisodeLength: 54.599998474121094
#
# Iteration: 31500, loss:0.20
# AverageReturn: -1.8100001811981201
# AverageEpisodeLength: 38.900001525878906
#
# Iteration: 32000, loss:0.25
# AverageReturn: -20.679996490478516
# AverageEpisodeLength: 97.19999694824219
#
# Iteration: 32500, loss:0.05
# AverageReturn: -14.079996109008789
# AverageEpisodeLength: 61.5
#
# Iteration: 33000, loss:0.05
# AverageReturn: -20.009984970092773
# AverageEpisodeLength: 85.69999694824219
#
# Iteration: 33500, loss:0.17
# AverageReturn: -6.659997463226318
# AverageEpisodeLength: 42.099998474121094
#
# Iteration: 34000, loss:0.19
# AverageReturn: -5.239999294281006
# AverageEpisodeLength: 40.0
#
# Iteration: 34500, loss:0.12
# AverageReturn: -20.91999626159668
# AverageEpisodeLength: 97.19999694824219
#
# Iteration: 35000, loss:0.31
# AverageReturn: -23.31001853942871
# AverageEpisodeLength: 93.80000305175781
#
# Iteration: 35500, loss:0.03
# AverageReturn: -8.989996910095215
# AverageEpisodeLength: 57.20000076293945
#
# Iteration: 36000, loss:0.13
# AverageReturn: -13.639993667602539
# AverageEpisodeLength: 67.80000305175781
#
# Iteration: 36500, loss:0.10
# AverageReturn: -2.8700006008148193
# AverageEpisodeLength: 31.0
#
# Iteration: 37000, loss:0.05
# AverageReturn: -13.069994926452637
# AverageEpisodeLength: 70.5999984741211
#
# Iteration: 37500, loss:0.13
# AverageReturn: -23.680025100708008
# AverageEpisodeLength: 101.9000015258789
#
# Iteration: 38000, loss:0.23
# AverageReturn: -18.010005950927734
# AverageEpisodeLength: 71.19999694824219
#
# Iteration: 38500, loss:0.20
# AverageReturn: -6.110001087188721
# AverageEpisodeLength: 29.899999618530273
#
# Iteration: 39000, loss:0.26
# AverageReturn: -4.210000514984131
# AverageEpisodeLength: 36.900001525878906
#
# Iteration: 39500, loss:0.09
# AverageReturn: -5.970000267028809
# AverageEpisodeLength: 30.700000762939453
#
# Iteration: 40000, loss:0.30
# AverageReturn: -9.389996528625488
# AverageEpisodeLength: 60.5
#
# Iteration: 40500, loss:0.10
# AverageReturn: -5.010000705718994
# AverageEpisodeLength: 41.900001525878906
#
# Iteration: 41000, loss:0.13
# AverageReturn: -8.59000015258789
# AverageEpisodeLength: 46.79999923706055
#
# Iteration: 41500, loss:0.13
# AverageReturn: -15.040006637573242
# AverageEpisodeLength: 71.4000015258789
#
# Iteration: 42000, loss:0.21
# AverageReturn: -14.6799955368042
# AverageEpisodeLength: 76.30000305175781
#
# Iteration: 42500, loss:0.13
# AverageReturn: -0.7500007152557373
# AverageEpisodeLength: 31.399999618530273
#
# Iteration: 43000, loss:0.19
# AverageReturn: -3.24999737739563
# AverageEpisodeLength: 44.099998474121094
#
# Iteration: 43500, loss:0.27
# AverageReturn: -4.9499993324279785
# AverageEpisodeLength: 35.20000076293945
#
# Iteration: 44000, loss:0.12
# AverageReturn: -5.6399993896484375
# AverageEpisodeLength: 40.599998474121094
#
# Iteration: 44500, loss:0.12
# AverageReturn: -10.009997367858887
# AverageEpisodeLength: 64.4000015258789
#
# Iteration: 45000, loss:0.12
# AverageReturn: -3.029998540878296
# AverageEpisodeLength: 44.5
#
# Iteration: 45500, loss:0.06
# AverageReturn: -6.009995460510254
# AverageEpisodeLength: 57.29999923706055
#
# Iteration: 46000, loss:0.22
# AverageReturn: -13.140002250671387
# AverageEpisodeLength: 74.5
#
# Iteration: 46500, loss:0.15
# AverageReturn: -4.1699981689453125
# AverageEpisodeLength: 47.599998474121094
#
# Iteration: 47000, loss:0.08
# AverageReturn: -5.999998092651367
# AverageEpisodeLength: 55.29999923706055
#
# Iteration: 47500, loss:0.11
# AverageReturn: -3.0500004291534424
# AverageEpisodeLength: 42.099998474121094
#
# Iteration: 48000, loss:0.18
# AverageReturn: -5.109999656677246
# AverageEpisodeLength: 45.0
#
# Iteration: 48500, loss:0.07
# AverageReturn: -2.699998140335083
# AverageEpisodeLength: 48.099998474121094
#
# Iteration: 49000, loss:0.14
# AverageReturn: -4.969998836517334
# AverageEpisodeLength: 56.0
#
# Iteration: 49500, loss:0.07
# AverageReturn: -5.219997882843018
# AverageEpisodeLength: 54.900001525878906
#
# Iteration: 50000, loss:0.11
# AverageReturn: -4.929999351501465
# AverageEpisodeLength: 46.599998474121094
#
# Iteration: 50500, loss:0.13
# AverageReturn: -2.5199971199035645
# AverageEpisodeLength: 49.70000076293945
#
# Iteration: 51000, loss:0.11
# AverageReturn: -20.080032348632812
# AverageEpisodeLength: 97.19999694824219
#
# Iteration: 51500, loss:0.16
# AverageReturn: -1.7999995946884155
# AverageEpisodeLength: 33.79999923706055
#
# Iteration: 52000, loss:0.29
# AverageReturn: -6.559998989105225
# AverageEpisodeLength: 43.099998474121094
#
# Iteration: 52500, loss:0.13
# AverageReturn: -3.6800003051757812
# AverageEpisodeLength: 44.400001525878906
#
# Iteration: 53000, loss:0.17
# AverageReturn: -5.719996929168701
# AverageEpisodeLength: 56.70000076293945
#
# Iteration: 53500, loss:0.11
# AverageReturn: 0.5400000214576721
# AverageEpisodeLength: 28.799999237060547
#
# Iteration: 54000, loss:0.05
# AverageReturn: 0.6499994993209839
# AverageEpisodeLength: 39.099998474121094
#
# Iteration: 54500, loss:0.16
# AverageReturn: -6.800000190734863
# AverageEpisodeLength: 47.20000076293945
#
# Iteration: 55000, loss:0.18
# AverageReturn: -6.40999698638916
# AverageEpisodeLength: 62.0
#
# Iteration: 55500, loss:0.15
# AverageReturn: -9.60999870300293
# AverageEpisodeLength: 60.0
#
# Iteration: 56000, loss:0.17
# AverageReturn: -5.619997978210449
# AverageEpisodeLength: 57.79999923706055
#
# Iteration: 56500, loss:0.24
# AverageReturn: -4.100003719329834
# AverageEpisodeLength: 54.5
#
# Iteration: 57000, loss:0.24
# AverageReturn: -1.5199997425079346
# AverageEpisodeLength: 57.900001525878906
#
# Iteration: 57500, loss:0.21
# AverageReturn: 3.0299999713897705
# AverageEpisodeLength: 37.400001525878906
#
# Iteration: 58000, loss:0.04
# AverageReturn: 2.789999008178711
# AverageEpisodeLength: 49.400001525878906
#
# Iteration: 58500, loss:0.11
# AverageReturn: -2.570000648498535
# AverageEpisodeLength: 43.79999923706055
#
# Iteration: 59000, loss:0.14
# AverageReturn: 3.3799991607666016
# AverageEpisodeLength: 40.29999923706055
#
# Iteration: 59500, loss:0.04
# AverageReturn: -2.3799970149993896
# AverageEpisodeLength: 50.0
#
# Iteration: 60000, loss:0.20
# AverageReturn: -1.259999394416809
# AverageEpisodeLength: 49.20000076293945
#
# Iteration: 60500, loss:0.22
# AverageReturn: -1.5200011730194092
# AverageEpisodeLength: 50.0
#
# Iteration: 61000, loss:0.13
# AverageReturn: -0.6100006699562073
# AverageEpisodeLength: 39.70000076293945
#
# Iteration: 61500, loss:0.36
# AverageReturn: 4.289999485015869
# AverageEpisodeLength: 31.200000762939453
#
# Iteration: 62000, loss:0.11
# AverageReturn: 2.2599995136260986
# AverageEpisodeLength: 33.400001525878906
#
# Iteration: 62500, loss:0.13
# AverageReturn: -5.229998588562012
# AverageEpisodeLength: 42.099998474121094
#
# Iteration: 63000, loss:0.17
# AverageReturn: 1.6699997186660767
# AverageEpisodeLength: 34.70000076293945
#
# Iteration: 63500, loss:0.24
# AverageReturn: 1.4999995231628418
# AverageEpisodeLength: 25.399999618530273
#
# Iteration: 64000, loss:0.25
# AverageReturn: -6.559996604919434
# AverageEpisodeLength: 49.79999923706055
#
# Iteration: 64500, loss:0.17
# AverageReturn: 8.619999885559082
# AverageEpisodeLength: 26.100000381469727
#
# Iteration: 65000, loss:0.06
# AverageReturn: 0.31999972462654114
# AverageEpisodeLength: 36.400001525878906
#
# Iteration: 65500, loss:0.17
# AverageReturn: 0.30000266432762146
# AverageEpisodeLength: 33.79999923706055
#
# Iteration: 66000, loss:0.21
# AverageReturn: 3.239999771118164
# AverageEpisodeLength: 26.600000381469727
#
# Iteration: 66500, loss:0.23
# AverageReturn: 1.4200001955032349
# AverageEpisodeLength: 39.29999923706055
#
# Iteration: 67000, loss:0.24
# AverageReturn: 0.48999935388565063
# AverageEpisodeLength: 32.20000076293945
#
# Iteration: 67500, loss:0.30
# AverageReturn: 4.809998989105225
# AverageEpisodeLength: 28.0
#
# Iteration: 68000, loss:0.22
# AverageReturn: 4.480000019073486
# AverageEpisodeLength: 22.899999618530273
#
# Iteration: 68500, loss:0.38
# AverageReturn: 2.0899994373321533
# AverageEpisodeLength: 35.79999923706055
#
# Iteration: 69000, loss:0.33
# AverageReturn: 1.4999991655349731
# AverageEpisodeLength: 28.899999618530273
#
# Iteration: 69500, loss:0.28
# AverageReturn: 5.559999942779541
# AverageEpisodeLength: 27.799999237060547
#
# Iteration: 70000, loss:0.42
# AverageReturn: -1.1799978017807007
# AverageEpisodeLength: 56.70000076293945
#
# Iteration: 70500, loss:0.34
# AverageReturn: 5.389998912811279
# AverageEpisodeLength: 27.600000381469727
#
# Iteration: 71000, loss:0.23
# AverageReturn: 6.479999542236328
# AverageEpisodeLength: 20.899999618530273
#
# Iteration: 71500, loss:0.22
# AverageReturn: -1.1099976301193237
# AverageEpisodeLength: 48.599998474121094
#
# Iteration: 72000, loss:0.50
# AverageReturn: 6.439999580383301
# AverageEpisodeLength: 28.100000381469727
#
# Iteration: 72500, loss:0.37
# AverageReturn: 6.629998683929443
# AverageEpisodeLength: 23.100000381469727
#
# Iteration: 73000, loss:0.19
# AverageReturn: -4.499998092651367
# AverageEpisodeLength: 50.900001525878906
#
# Iteration: 73500, loss:0.29
# AverageReturn: -0.4500001072883606
# AverageEpisodeLength: 36.5
#
# Iteration: 74000, loss:0.28
# AverageReturn: 4.95999813079834
# AverageEpisodeLength: 23.299999237060547
#
# Iteration: 74500, loss:0.27
# AverageReturn: -6.329998970031738
# AverageEpisodeLength: 46.70000076293945
#
# Iteration: 75000, loss:0.33
# AverageReturn: 2.7699997425079346
# AverageEpisodeLength: 22.5
#
# Iteration: 75500, loss:0.42
# AverageReturn: 2.3999996185302734
# AverageEpisodeLength: 32.29999923706055
#
# Iteration: 76000, loss:0.46
# AverageReturn: 2.3299996852874756
# AverageEpisodeLength: 29.799999237060547
#
# Iteration: 76500, loss:0.33
# AverageReturn: 3.2099997997283936
# AverageEpisodeLength: 38.599998474121094
#
# Iteration: 77000, loss:0.23
# AverageReturn: -1.2699991464614868
# AverageEpisodeLength: 47.5
#
# Iteration: 77500, loss:0.34
# AverageReturn: 7.0899977684021
# AverageEpisodeLength: 30.399999618530273
#
# Iteration: 78000, loss:0.32
# AverageReturn: 2.1600005626678467
# AverageEpisodeLength: 41.29999923706055
#
# Iteration: 78500, loss:0.47
# AverageReturn: 4.119998931884766
# AverageEpisodeLength: 28.700000762939453
#
# Iteration: 79000, loss:0.33
# AverageReturn: 0.6299988031387329
# AverageEpisodeLength: 37.70000076293945
#
# Iteration: 79500, loss:0.30
# AverageReturn: 4.7299981117248535
# AverageEpisodeLength: 43.70000076293945
#
# Iteration: 80000, loss:0.42
# AverageReturn: 3.349999189376831
# AverageEpisodeLength: 40.20000076293945
#
# Iteration: 80500, loss:0.40
# AverageReturn: 9.039998054504395
# AverageEpisodeLength: 32.79999923706055
#
# Iteration: 81000, loss:0.40
# AverageReturn: 8.369998931884766
# AverageEpisodeLength: 31.899999618530273
#
# Iteration: 81500, loss:0.42
# AverageReturn: 4.689999580383301
# AverageEpisodeLength: 25.700000762939453
#
# Iteration: 82000, loss:0.36
# AverageReturn: 8.969998359680176
# AverageEpisodeLength: 27.200000762939453
#
# Iteration: 82500, loss:0.45
# AverageReturn: 3.2500014305114746
# AverageEpisodeLength: 44.79999923706055
#
# Iteration: 83000, loss:0.46
# AverageReturn: 6.869997978210449
# AverageEpisodeLength: 31.799999237060547
#
# Iteration: 83500, loss:0.46
# AverageReturn: 6.609999179840088
# AverageEpisodeLength: 33.79999923706055
#
# Iteration: 84000, loss:0.56
# AverageReturn: 7.779998779296875
# AverageEpisodeLength: 28.100000381469727
#
# Iteration: 84500, loss:0.34
# AverageReturn: 8.36999797821045
# AverageEpisodeLength: 26.5
#
# Iteration: 85000, loss:0.42
# AverageReturn: 7.249999046325684
# AverageEpisodeLength: 31.0
#
# Iteration: 85500, loss:0.42
# AverageReturn: 10.789999008178711
# AverageEpisodeLength: 28.299999237060547
#
# Iteration: 86000, loss:0.74
# AverageReturn: 6.799999237060547
# AverageEpisodeLength: 33.400001525878906
#
# Iteration: 86500, loss:0.25
# AverageReturn: 4.260000228881836
# AverageEpisodeLength: 43.70000076293945
#
# Iteration: 87000, loss:0.24
# AverageReturn: 10.34999942779541
# AverageEpisodeLength: 27.200000762939453
#
# Iteration: 87500, loss:0.49
# AverageReturn: 13.960000991821289
# AverageEpisodeLength: 18.799999237060547
#
# Iteration: 88000, loss:0.23
# AverageReturn: 3.169999599456787
# AverageEpisodeLength: 36.5
#
# Iteration: 88500, loss:0.44
# AverageReturn: 12.199999809265137
# AverageEpisodeLength: 18.899999618530273
#
# Iteration: 89000, loss:0.43
# AverageReturn: 7.259999752044678
# AverageEpisodeLength: 29.600000381469727
#
# Iteration: 89500, loss:0.26
# AverageReturn: 7.359999656677246
# AverageEpisodeLength: 18.100000381469727
#
# Iteration: 90000, loss:0.44
# AverageReturn: 14.579998970031738
# AverageEpisodeLength: 21.299999237060547
#
# Iteration: 90500, loss:0.56
# AverageReturn: 10.35999870300293
# AverageEpisodeLength: 25.100000381469727
#
# Iteration: 91000, loss:0.26
# AverageReturn: 6.5799994468688965
# AverageEpisodeLength: 25.799999237060547
#
# Iteration: 91500, loss:0.35
# AverageReturn: 5.659998893737793
# AverageEpisodeLength: 26.200000762939453
#
# Iteration: 92000, loss:0.64
# AverageReturn: 7.339999198913574
# AverageEpisodeLength: 30.799999237060547
#
# Iteration: 92500, loss:0.29
# AverageReturn: -3.089998722076416
# AverageEpisodeLength: 55.70000076293945
#
# Iteration: 93000, loss:0.34
# AverageReturn: -10.219999313354492
# AverageEpisodeLength: 74.5999984741211
#
# Iteration: 93500, loss:0.46
# AverageReturn: 10.809998512268066
# AverageEpisodeLength: 28.399999618530273
#
# Iteration: 94000, loss:0.63
# AverageReturn: -2.589996814727783
# AverageEpisodeLength: 61.400001525878906
#
# Iteration: 94500, loss:0.46
# AverageReturn: -8.75
# AverageEpisodeLength: 68.5999984741211
#
# Iteration: 95000, loss:0.41
# AverageReturn: 5.349998950958252
# AverageEpisodeLength: 25.799999237060547
#
# Iteration: 95500, loss:0.33
# AverageReturn: 0.440000057220459
# AverageEpisodeLength: 50.599998474121094
#
# Iteration: 96000, loss:0.65
# AverageReturn: -11.699995040893555
# AverageEpisodeLength: 84.0999984741211
#
# Iteration: 96500, loss:0.54
# AverageReturn: 4.470000743865967
# AverageEpisodeLength: 45.900001525878906
#
# Iteration: 97000, loss:0.49
# AverageReturn: 7.789999485015869
# AverageEpisodeLength: 30.5
#
# Iteration: 97500, loss:0.35
# AverageReturn: 3.1699936389923096
# AverageEpisodeLength: 43.400001525878906
#
# Iteration: 98000, loss:0.63
# AverageReturn: -1.0899970531463623
# AverageEpisodeLength: 57.5
#
# Iteration: 98500, loss:0.54
# AverageReturn: 5.909998416900635
# AverageEpisodeLength: 37.79999923706055
#
# Iteration: 99000, loss:0.37
# AverageReturn: -0.04999961704015732
# AverageEpisodeLength: 55.70000076293945
#
# Iteration: 99500, loss:0.48
# AverageReturn: -5.299999713897705
# AverageEpisodeLength: 58.70000076293945
#
# Iteration: 100000, loss:0.67
# AverageReturn: -10.410024642944336
# AverageEpisodeLength: 76.80000305175781
#
# Iteration: 100500, loss:0.75
# AverageReturn: 3.1499969959259033
# AverageEpisodeLength: 44.5
#
# Iteration: 101000, loss:0.52
# AverageReturn: -2.730006694793701
# AverageEpisodeLength: 67.5999984741211
#
# Iteration: 101500, loss:0.24
# AverageReturn: 9.379997253417969
# AverageEpisodeLength: 36.400001525878906
#
# Iteration: 102000, loss:0.62
# AverageReturn: 6.469998836517334
# AverageEpisodeLength: 33.400001525878906
#
# Iteration: 102500, loss:0.39
# AverageReturn: 11.339999198913574
# AverageEpisodeLength: 31.600000381469727
#
# Iteration: 103000, loss:0.42
# AverageReturn: 4.9499993324279785
# AverageEpisodeLength: 32.900001525878906
#
# Iteration: 103500, loss:0.28
# AverageReturn: 9.869999885559082
# AverageEpisodeLength: 22.399999618530273
#
# Iteration: 104000, loss:0.62
# AverageReturn: 11.719999313354492
# AverageEpisodeLength: 28.200000762939453
#
# Iteration: 104500, loss:0.50
# AverageReturn: 10.229999542236328
# AverageEpisodeLength: 26.299999237060547
#
# Iteration: 105000, loss:0.59
# AverageReturn: 17.28999900817871
# AverageEpisodeLength: 16.600000381469727
#
# Iteration: 105500, loss:0.47
# AverageReturn: 7.280004978179932
# AverageEpisodeLength: 42.79999923706055
#
# Iteration: 106000, loss:0.63
# AverageReturn: 0.6100068092346191
# AverageEpisodeLength: 52.20000076293945
#
# Iteration: 106500, loss:0.60
# AverageReturn: -9.010049819946289
# AverageEpisodeLength: 84.69999694824219
#
# Iteration: 107000, loss:0.57
# AverageReturn: 16.130001068115234
# AverageEpisodeLength: 15.199999809265137
#
# Iteration: 107500, loss:0.30
# AverageReturn: 5.600005149841309
# AverageEpisodeLength: 40.20000076293945
#
# Iteration: 108000, loss:0.70
# AverageReturn: 7.229998588562012
# AverageEpisodeLength: 33.70000076293945
#
# Iteration: 108500, loss:0.41
# AverageReturn: 12.489998817443848
# AverageEpisodeLength: 23.5
#
# Iteration: 109000, loss:0.22
# AverageReturn: -8.12000846862793
# AverageEpisodeLength: 80.5
#
# Iteration: 109500, loss:0.62
# AverageReturn: 11.189998626708984
# AverageEpisodeLength: 27.899999618530273
#
# Iteration: 110000, loss:0.63
# AverageReturn: 9.69999885559082
# AverageEpisodeLength: 35.5
#
# Iteration: 110500, loss:0.37
# AverageReturn: 15.210000991821289
# AverageEpisodeLength: 22.100000381469727
#
# Iteration: 111000, loss:0.34
# AverageReturn: 14.079998970031738
# AverageEpisodeLength: 27.399999618530273
#
# Iteration: 111500, loss:0.36
# AverageReturn: 2.6000003814697266
# AverageEpisodeLength: 48.20000076293945
#
# Iteration: 112000, loss:0.54
# AverageReturn: -5.840018272399902
# AverageEpisodeLength: 76.0
#
# Iteration: 112500, loss:0.46
# AverageReturn: 14.709997177124023
# AverageEpisodeLength: 25.5
#
# Iteration: 113000, loss:0.44
# AverageReturn: 3.860002040863037
# AverageEpisodeLength: 53.599998474121094
#
# Iteration: 113500, loss:0.44
# AverageReturn: 15.089996337890625
# AverageEpisodeLength: 26.5
#
# Iteration: 114000, loss:0.43
# AverageReturn: 14.309999465942383
# AverageEpisodeLength: 21.100000381469727
#
# Iteration: 114500, loss:0.40
# AverageReturn: -0.07999162375926971
# AverageEpisodeLength: 57.29999923706055
#
# Iteration: 115000, loss:0.53
# AverageReturn: 11.829998016357422
# AverageEpisodeLength: 31.0
#
# Iteration: 115500, loss:0.27
# AverageReturn: -5.030005931854248
# AverageEpisodeLength: 70.5
#
# Iteration: 116000, loss:0.45
# AverageReturn: 8.75999927520752
# AverageEpisodeLength: 19.399999618530273
#
# Iteration: 116500, loss:0.47
# AverageReturn: -1.0999962091445923
# AverageEpisodeLength: 57.5
#
# Iteration: 117000, loss:0.24
# AverageReturn: -2.7100043296813965
# AverageEpisodeLength: 55.20000076293945
#
# Iteration: 117500, loss:0.37
# AverageReturn: 6.449998378753662
# AverageEpisodeLength: 37.70000076293945
#
# Iteration: 118000, loss:0.49
# AverageReturn: 15.44999885559082
# AverageEpisodeLength: 18.700000762939453
#
# Iteration: 118500, loss:0.37
# AverageReturn: -10.0600004196167
# AverageEpisodeLength: 79.19999694824219
#
# Iteration: 119000, loss:0.39
# AverageReturn: 0.10999679565429688
# AverageEpisodeLength: 51.099998474121094
#
# Iteration: 119500, loss:0.31
# AverageReturn: -2.490003824234009
# AverageEpisodeLength: 52.0
#
# Iteration: 120000, loss:0.35
# AverageReturn: -19.010019302368164
# AverageEpisodeLength: 99.0
#
# Iteration: 120500, loss:0.28
# AverageReturn: 2.140002727508545
# AverageEpisodeLength: 45.0
#
# Iteration: 121000, loss:0.24
# AverageReturn: 8.529998779296875
# AverageEpisodeLength: 36.5
#
# Iteration: 121500, loss:0.45
# AverageReturn: -7.9600019454956055
# AverageEpisodeLength: 60.099998474121094
#
# Iteration: 122000, loss:0.23
# AverageReturn: -20.44002342224121
# AverageEpisodeLength: 106.5
#
# Iteration: 122500, loss:0.27
# AverageReturn: -12.75998592376709
# AverageEpisodeLength: 76.5
#
# Iteration: 123000, loss:0.40
# AverageReturn: -16.98999786376953
# AverageEpisodeLength: 110.5999984741211
#
# Iteration: 123500, loss:0.36
# AverageReturn: -50.949729919433594
# AverageEpisodeLength: 184.5
#
# Iteration: 124000, loss:0.22
# AverageReturn: -44.310001373291016
# AverageEpisodeLength: 150.60000610351562
#
# Iteration: 124500, loss:0.31
# AverageReturn: -7.570001125335693
# AverageEpisodeLength: 62.400001525878906
#
# Iteration: 125000, loss:0.25
# AverageReturn: -23.89000701904297
# AverageEpisodeLength: 125.5999984741211
#
# Iteration: 125500, loss:0.50
# AverageReturn: -0.31000080704689026
# AverageEpisodeLength: 50.70000076293945
#
# Iteration: 126000, loss:0.32
# AverageReturn: 3.660001277923584
# AverageEpisodeLength: 26.700000762939453
#
# Iteration: 126500, loss:0.21
# AverageReturn: -26.170150756835938
# AverageEpisodeLength: 153.10000610351562
#
# Iteration: 127000, loss:0.28
# AverageReturn: 1.7700055837631226
# AverageEpisodeLength: 42.5
#
# Iteration: 127500, loss:0.25
# AverageReturn: 7.999998569488525
# AverageEpisodeLength: 16.200000762939453
#
# Iteration: 128000, loss:0.17
# AverageReturn: 6.45999813079834
# AverageEpisodeLength: 40.70000076293945
#
# Iteration: 128500, loss:0.20
# AverageReturn: 12.170001029968262
# AverageEpisodeLength: 34.29999923706055
#
# Iteration: 129000, loss:0.34
# AverageReturn: 20.099998474121094
# AverageEpisodeLength: 15.199999809265137
#
# Iteration: 129500, loss:0.32
# AverageReturn: 19.009998321533203
# AverageEpisodeLength: 15.199999809265137
#
# Iteration: 130000, loss:0.41
# AverageReturn: 19.1299991607666
# AverageEpisodeLength: 14.600000381469727
#
# Iteration: 130500, loss:0.27
# AverageReturn: -43.82001876831055
# AverageEpisodeLength: 158.0
#
# Iteration: 131000, loss:0.19
# AverageReturn: -17.860004425048828
# AverageEpisodeLength: 87.69999694824219
#
# Iteration: 131500, loss:0.31
# AverageReturn: -16.25
# AverageEpisodeLength: 93.5
#
# Iteration: 132000, loss:0.32
# AverageReturn: 0.5599996447563171
# AverageEpisodeLength: 53.70000076293945
#
# Iteration: 132500, loss:0.49
# AverageReturn: -117.04972839355469
# AverageEpisodeLength: 322.0
#
# Iteration: 133000, loss:0.28
# AverageReturn: -27.14004135131836
# AverageEpisodeLength: 103.0
#
# Iteration: 133500, loss:0.41
# AverageReturn: -114.74983978271484
# AverageEpisodeLength: 301.8999938964844
#
# Iteration: 134000, loss:0.26
# AverageReturn: -130.10963439941406
# AverageEpisodeLength: 335.5
#
# Iteration: 134500, loss:0.23
# AverageReturn: -13.43999195098877
# AverageEpisodeLength: 122.9000015258789
#
# Iteration: 135000, loss:0.23
# AverageReturn: 12.090002059936523
# AverageEpisodeLength: 37.20000076293945
#
# Iteration: 135500, loss:0.23
# AverageReturn: 6.969970703125
# AverageEpisodeLength: 58.0
#
# Iteration: 136000, loss:0.11
# AverageReturn: 11.940000534057617
# AverageEpisodeLength: 40.400001525878906
#
# Iteration: 136500, loss:0.29
# AverageReturn: 15.61999797821045
# AverageEpisodeLength: 20.200000762939453
#
# Iteration: 137000, loss:0.29
# AverageReturn: 19.239999771118164
# AverageEpisodeLength: 17.799999237060547
#
# Iteration: 137500, loss:0.17
# AverageReturn: 16.310001373291016
# AverageEpisodeLength: 21.200000762939453
#
# Iteration: 138000, loss:0.22
# AverageReturn: 18.449996948242188
# AverageEpisodeLength: 20.399999618530273
#
# Iteration: 138500, loss:0.31
# AverageReturn: 8.659996032714844
# AverageEpisodeLength: 43.5
#
# Iteration: 139000, loss:0.34
# AverageReturn: -11.090002059936523
# AverageEpisodeLength: 84.5999984741211
#
# Iteration: 139500, loss:0.32
# AverageReturn: 15.179998397827148
# AverageEpisodeLength: 29.799999237060547
#
# Iteration: 140000, loss:0.15
# AverageReturn: 1.739996314048767
# AverageEpisodeLength: 57.599998474121094
#
# Iteration: 140500, loss:0.22
# AverageReturn: -2.8899927139282227
# AverageEpisodeLength: 68.80000305175781
#
# Iteration: 141000, loss:0.13
# AverageReturn: -8.120012283325195
# AverageEpisodeLength: 96.0
#
# Iteration: 141500, loss:0.20
# AverageReturn: 14.789999008178711
# AverageEpisodeLength: 28.600000381469727
#
# Iteration: 142000, loss:0.26
# AverageReturn: -3.790015697479248
# AverageEpisodeLength: 82.30000305175781
#
# Iteration: 142500, loss:0.33
# AverageReturn: 12.489998817443848
# AverageEpisodeLength: 18.5
#
# Iteration: 143000, loss:0.18
# AverageReturn: 10.859997749328613
# AverageEpisodeLength: 25.100000381469727
#
# Iteration: 143500, loss:0.21
# AverageReturn: -1.6699943542480469
# AverageEpisodeLength: 40.400001525878906
#
# Iteration: 144000, loss:0.26
# AverageReturn: 17.319997787475586
# AverageEpisodeLength: 18.0
#
# Iteration: 144500, loss:0.20
# AverageReturn: 18.389999389648438
# AverageEpisodeLength: 20.700000762939453
#
# Iteration: 145000, loss:0.28
# AverageReturn: 16.229999542236328
# AverageEpisodeLength: 14.600000381469727
#
# Iteration: 145500, loss:0.21
# AverageReturn: 11.759998321533203
# AverageEpisodeLength: 18.799999237060547
#
# Iteration: 146000, loss:0.16
# AverageReturn: 14.749998092651367
# AverageEpisodeLength: 13.600000381469727
#
# Iteration: 146500, loss:0.38
# AverageReturn: 18.92999839782715
# AverageEpisodeLength: 18.899999618530273
#
# Iteration: 147000, loss:0.19
# AverageReturn: 17.049999237060547
# AverageEpisodeLength: 14.600000381469727
#
# Iteration: 147500, loss:0.13
# AverageReturn: 14.44999885559082
# AverageEpisodeLength: 20.100000381469727
#
# Iteration: 148000, loss:0.22
# AverageReturn: 9.519999504089355
# AverageEpisodeLength: 20.899999618530273
#
# Iteration: 148500, loss:0.26
# AverageReturn: 18.509998321533203
# AverageEpisodeLength: 20.299999237060547
#
# Iteration: 149000, loss:0.41
# AverageReturn: 19.909997940063477
# AverageEpisodeLength: 19.299999237060547
#
# Iteration: 149500, loss:0.29
# AverageReturn: 19.44999885559082
# AverageEpisodeLength: 19.100000381469727

# %%
avg_return_trained = column(all_metrics,0)
avg_ep_trained = column(all_metrics,1)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,15))

axs[0].plot(range(len(avg_return_trained)), avg_return_trained)
axs[0].set_title('Average Return')

axs[1].plot(range(len(avg_ep_trained)), avg_ep_trained, 'tab:orange')
axs[1].set_title('Average Episode Length')

for ax in axs.flat:
    ax.set(xlabel='Number of Iterations', ylabel='Metric Value')

# %% [markdown]
# ### Evaluate

# %%
def compute_avg_return(environment, policy, num_episodes=10):

    total_return = 0.0
    
    for _ in range(num_episodes):
        time_step = environment.reset()
        episode_return = 0.0
        
        while not time_step.is_last():
            action_step = policy.action(time_step)
            time_step = environment.step(action_step.action)
            episode_return += time_step.reward
        
        total_return += episode_return

    avg_return = total_return / num_episodes
    
    return avg_return.numpy()[0]

# %%
# Reset the train step
agent.train_step_counter.assign(0)

#reset eval environment
eval_env.reset()

# Evaluate the agent's policy once before training.
avg_return = compute_avg_return(eval_env, agent.policy, 5)

# %%
avg_return
# Out:
# 19.3

# %% [markdown]
# ### Visualize Episode

# %%
def observation_viz(observation):
    numpy_obs = observation.numpy()[0]
    string_obs = np.array(np.reshape(numpy_obs, (-1, 6)), dtype=np.unicode_)
    if string_obs[5][5] != "1":
      string_obs[5][5] = "❌"
    string_obs = np.where(string_obs=="1","🐕", string_obs) 
    string_obs = np.where(string_obs=="2","🤖", string_obs)
    string_obs = np.where(string_obs=="3","🦴", string_obs)
    string_obs = np.where(string_obs=="0","⬚", string_obs)
    string_obs = np.where(string_obs=="4","🐈", string_obs)
    observe_2d = pd.DataFrame(string_obs)
    observe_2d.columns = [''] * len(observe_2d.columns)
    observe_2d = observe_2d.to_string(index=False)
    print("\n{}\n".format(observe_2d))

# %%
def compute_viz(environment, policy, num_episodes=10):

    total_return = 0.0
    
    for _ in range(num_episodes):
        time_step = environment.reset()
        episode_return = 0.0
        step = 0
        print("Step: 0")
        observation_viz(time_step.observation)
        while not time_step.is_last():
            step += 1
            print("---\nStep: {}".format(step))
            action_step = policy.action(time_step)
            print("Action taken: {}".format(action_step.action))
            time_step = environment.step(action_step.action)
            observation_viz(time_step.observation)
            episode_return += time_step.reward
            print("Reward: {} \n".format(episode_return))
        
        total_return += episode_return

    avg_return = total_return / num_episodes
    
    return avg_return.numpy()[0]

# %%
# Reset the train step
agent.train_step_counter.assign(0)

#reset eval environment
eval_env.reset()

# Evaluate the agent's policy once before training.
avg_return = compute_viz(eval_env, agent.policy, 1)
# Out:
# Step: 0
#
#
#  🐕  🐈  ⬚  ⬚  ⬚  🦴
#  ⬚  🦴  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# ---
# Step: 1
# Action taken: [11]
#
#
#  🐕  ⬚  ⬚  ⬚  ⬚  🦴
#  ⬚  🐈  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [1.]
#
# ---
# Step: 2
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🦴
#  🐕  🐈  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [0.7]
#
# ---
# Step: 3
# Action taken: [0]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  🐕
#  ⬚  🐈  ⬚  🦴  🤖  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [1.7]
#
# ---
# Step: 4
# Action taken: [5]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  🐈  ⬚  🦴  🐕  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [3.7]
#
# ---
# Step: 5
# Action taken: [0]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  🐈  ⬚  🐕  ⬚  ⬚
#  ⬚  ⬚  🤖  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [4.7]
#
# ---
# Step: 6
# Action taken: [12]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  🐕  ⬚  ⬚
#  ⬚  ⬚  🐈  ⬚  🦴  ⬚
#  ⬚  🦴  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [6.7]
#
# ---
# Step: 7
# Action taken: [11]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  🐕  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  🦴  ⬚
#  ⬚  🦴  🐈  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [6.3999996]
#
# ---
# Step: 8
# Action taken: [8]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  🐕  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  🦴  ⬚
#  ⬚  🐈  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [7.3999996]
#
# ---
# Step: 9
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  🐕  🦴  ⬚
#  ⬚  🐈  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [7.0999994]
#
# ---
# Step: 10
# Action taken: [8]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  🐕  🦴  ⬚
#  🐈  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  🤖  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [6.799999]
#
# ---
# Step: 11
# Action taken: [12]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  🐕  🦴  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  🐈  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [8.799999]
#
# ---
# Step: 12
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  🦴  ⬚
#  ⬚  ⬚  ⬚  🐕  ⬚  ⬚
#  ⬚  🐈  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [8.499999]
#
# ---
# Step: 13
# Action taken: [1]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  🦴  ⬚
#  ⬚  ⬚  ⬚  ⬚  🐕  ⬚
#  ⬚  🐈  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [8.199999]
#
# ---
# Step: 14
# Action taken: [1]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  🦴  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  🐕
#  ⬚  🐈  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [7.8999987]
#
# ---
# Step: 15
# Action taken: [10]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  🦴  ⬚
#  ⬚  🐈  ⬚  ⬚  ⬚  🐕
#  ⬚  ⬚  🦴  ⬚  🤖  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [7.5999985]
#
# ---
# Step: 16
# Action taken: [5]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  🦴  ⬚
#  ⬚  🐈  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  🦴  ⬚  🐕  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  ❌
#
# Reward: [9.599998]
#
# ---
# Step: 17
# Action taken: [3]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  🦴  ⬚
#  ⬚  🐈  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  ⬚  🐕  ❌
#
# Reward: [9.299998]
#
# ---
# Step: 18
# Action taken: [1]
#
#
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  ⬚  ⬚  🦴  ⬚
#  ⬚  🐈  ⬚  ⬚  ⬚  ⬚
#  ⬚  ⬚  🦴  ⬚  ⬚  ⬚
#  🦴  ⬚  ⬚  ⬚  ⬚  🐕
#
# Reward: [19.3]

# %% [markdown]
# ### Checkpoint Saver

# %%
import os

tempdir = "/content/"

checkpoint_dir = os.path.join(tempdir, 'checkpoint')
train_checkpointer = common.Checkpointer(
    ckpt_dir=checkpoint_dir,
    max_to_keep=1,
    agent=agent,
    policy=agent.policy,
    replay_buffer=replay_buffer,
    global_step=train_step
)

# %%
train_checkpointer.save(train_step)

# %%
# !zip -r saved_checkpoint.zip /content/checkpoint
# Out:
#   adding: content/checkpoint/ (stored 0%)
#   adding: content/checkpoint/checkpoint (deflated 41%)
#   adding: content/checkpoint/ckpt-0.data-00000-of-00001 (deflated 97%)
#   adding: content/checkpoint/ckpt-0.index (deflated 65%)

# %% [markdown]
# ### Policy Saver

# %%
policy_dir = os.path.join(tempdir, 'policy')
tf_policy_saver = policy_saver.PolicySaver(agent.policy)

# %%
tf_policy_saver.save(policy_dir)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /content/policy/assets
# INFO:tensorflow:Assets written to: /content/policy/assets

# %%
# !zip -r saved_policy.zip /content/policy/
# Out:
#   adding: content/policy/ (stored 0%)
#   adding: content/policy/variables/ (stored 0%)
#   adding: content/policy/variables/variables.index (deflated 41%)
#   adding: content/policy/variables/variables.data-00000-of-00001 (deflated 16%)
#   adding: content/policy/assets/ (stored 0%)
#   adding: content/policy/saved_model.pb (deflated 84%)

# %% [markdown]
# #### Loading the policy

# %%
loaded_policy = tf.saved_model.load("/content/policy")

# %%
eval_timestep = eval_env.reset()
loaded_action = loaded_policy.action(eval_timestep)
print(loaded_action)
# Out:
# PolicyStep(action=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([11], dtype=int32)>, state=(), info=())
